# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction.text import TfidfTransformer,TfidfVectorizer,CountVectorizer
from sklearn import metrics
from sklearn.metrics import roc_curve,auc

# %%
import re
import nltk
import string
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
import tqdm

# %%
from gensim.models import word2vec
from gensim.models import keyedvectors
import pickle,os,json,warnings

# %% [markdown]
# <div style="background-color:#202123; color:#ffffff; padding:8px 14px; border-radius:6px;">
#   <h2 style="margin:6px 0; color:#ffffff;">
#     1 INTRODUCTION
#   </h2>
# </div>
#
# The Amazon Product Reviews dataset contains user-generated reviews for a wide range of products sold on Amazon. Each record represents a single review and includes both unstructured text data and structured metadata, making it suitable for Natural Language Processing (NLP) and sentiment analysis tasks.
#
# The dataset captures customer opinions in the form of review text and ratings, along with contextual information such as purchase verification, review time, and product identifiers. Due to the large number of product categories, analysis is typically performed on a subset of categories, while the insights and methodologies can be generalized to other categories.
# REFERENCE - <a href = "https://nijianmo.github.io/amazon/">https://nijianmo.github.io/amazon/</a>

# %% [markdown]
# <div style="background-color:#202123; color:#ffffff; padding:8px 14px; border-radius:6px;">
#   <h2 style="margin:6px 0; color:#ffffff;">
#     2 Data Loading
#   </h2>
# </div>

# %%
import pandas as pd
import gzip

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield json.loads(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

# %%
df_fashion = getDF('Dataset/Dataset/All_Beauty_5.json.gz')
amazon_fashion = getDF("Dataset/Dataset/AMAZON_FASHION_5.json.gz")
appliances_5 = getDF('Dataset/Dataset/Appliances_5.json.gz')

# %%
appliances_5.head()
df=pd.concat([df_fashion,amazon_fashion,appliances_5])
df.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0      5.0      True   09 1, 2016  A3CIUOJXQ5VDQ2  B0000530HU
# 1      5.0      True  11 14, 2013  A3H7T87S984REU  B0000530HU
# 2      1.0      True  08 18, 2013  A3J034YH7UG4KT  B0000530HU
# 3      5.0     False   05 3, 2011  A2UEO5XR3598GI  B0000530HU
# 4      5.0      True   05 6, 2011  A3SFRT223XXWF7  B00006L9LC
#
#                                                style     reviewerName  \
# 0  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...         Shelly F
# 1  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...     houserules18
# 2  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...             Adam
# 3  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...           Rich K
# 4                          {'Size:': ' 200ml/6.7oz'}  C. C. Christian
#
#                                           reviewText  \
# 0                   As advertised. Reasonably priced
# 1  Like the oder and the feel when I put it on my...
# 2  I bought this to smell nice after I shave.  Wh...
# 3  HEY!! I am an Aqua Velva Man and absolutely lo...
# 4  If you ever want to feel pampered by a shampoo...
#
#                                              summary  unixReviewTime vote  \
# 0                                         Five Stars      1472688000  NaN
# 1                                  Good for the face      1384387200  NaN
# 2                                       Smells awful      1376784000  NaN
# 3  Truth is There IS Nothing Like an AQUA VELVA MAN.      1304380800   25
# 4                                    Bvlgari Shampoo      1304640000    3
#
#   image
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
df.to_csv("Dataset/Dataset/data",index=False)

# %% [markdown]
# <h2>Droping rows where overall=3</h2>

# %%
df=df.loc[df["overall"]!=3,:]

# %%
df.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0      5.0      True   09 1, 2016  A3CIUOJXQ5VDQ2  B0000530HU
# 1      5.0      True  11 14, 2013  A3H7T87S984REU  B0000530HU
# 2      1.0      True  08 18, 2013  A3J034YH7UG4KT  B0000530HU
# 3      5.0     False   05 3, 2011  A2UEO5XR3598GI  B0000530HU
# 4      5.0      True   05 6, 2011  A3SFRT223XXWF7  B00006L9LC
#
#                                                style     reviewerName  \
# 0  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...         Shelly F
# 1  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...     houserules18
# 2  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...             Adam
# 3  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...           Rich K
# 4                          {'Size:': ' 200ml/6.7oz'}  C. C. Christian
#
#                                           reviewText  \
# 0                   As advertised. Reasonably priced
# 1  Like the oder and the feel when I put it on my...
# 2  I bought this to smell nice after I shave.  Wh...
# 3  HEY!! I am an Aqua Velva Man and absolutely lo...
# 4  If you ever want to feel pampered by a shampoo...
#
#                                              summary  unixReviewTime vote  \
# 0                                         Five Stars      1472688000  NaN
# 1                                  Good for the face      1384387200  NaN
# 2                                       Smells awful      1376784000  NaN
# 3  Truth is There IS Nothing Like an AQUA VELVA MAN.      1304380800   25
# 4                                    Bvlgari Shampoo      1304640000    3
#
#   image
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %% [markdown]
# <h2>Convering unix time to pandas date</h2>

# %%
df["unixTime"]=pd.to_datetime(df["unixReviewTime"],unit='s')

# %%
df.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0      5.0      True   09 1, 2016  A3CIUOJXQ5VDQ2  B0000530HU
# 1      5.0      True  11 14, 2013  A3H7T87S984REU  B0000530HU
# 2      1.0      True  08 18, 2013  A3J034YH7UG4KT  B0000530HU
# 3      5.0     False   05 3, 2011  A2UEO5XR3598GI  B0000530HU
# 4      5.0      True   05 6, 2011  A3SFRT223XXWF7  B00006L9LC
#
#                                                style     reviewerName  \
# 0  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...         Shelly F
# 1  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...     houserules18
# 2  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...             Adam
# 3  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...           Rich K
# 4                          {'Size:': ' 200ml/6.7oz'}  C. C. Christian
#
#                                           reviewText  \
# 0                   As advertised. Reasonably priced
# 1  Like the oder and the feel when I put it on my...
# 2  I bought this to smell nice after I shave.  Wh...
# 3  HEY!! I am an Aqua Velva Man and absolutely lo...
# 4  If you ever want to feel pampered by a shampoo...
#
#                                              summary  unixReviewTime vote  \
# 0                                         Five Stars      1472688000  NaN
# 1                                  Good for the face      1384387200  NaN
# 2                                       Smells awful      1376784000  NaN
# 3  Truth is There IS Nothing Like an AQUA VELVA MAN.      1304380800   25
# 4                                    Bvlgari Shampoo      1304640000    3
#
#   image   unixTime
# 0   NaN 2016-09-01
# 1   NaN 2013-11-14
# 2   NaN 2013-08-18
# 3   NaN 2011-05-03
# 4   NaN 2011-05-06

# %% [markdown]
# <h2>adding a new column where overal greater than 3 having valuw 1 and less than 3 having value 0</h2>

# %%
df["Score"] = np.where(df["overall"]>3,1,0)

# %%
df.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0      5.0      True   09 1, 2016  A3CIUOJXQ5VDQ2  B0000530HU
# 1      5.0      True  11 14, 2013  A3H7T87S984REU  B0000530HU
# 2      1.0      True  08 18, 2013  A3J034YH7UG4KT  B0000530HU
# 3      5.0     False   05 3, 2011  A2UEO5XR3598GI  B0000530HU
# 4      5.0      True   05 6, 2011  A3SFRT223XXWF7  B00006L9LC
#
#                                                style     reviewerName  \
# 0  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...         Shelly F
# 1  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...     houserules18
# 2  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...             Adam
# 3  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...           Rich K
# 4                          {'Size:': ' 200ml/6.7oz'}  C. C. Christian
#
#                                           reviewText  \
# 0                   As advertised. Reasonably priced
# 1  Like the oder and the feel when I put it on my...
# 2  I bought this to smell nice after I shave.  Wh...
# 3  HEY!! I am an Aqua Velva Man and absolutely lo...
# 4  If you ever want to feel pampered by a shampoo...
#
#                                              summary  unixReviewTime vote  \
# 0                                         Five Stars      1472688000  NaN
# 1                                  Good for the face      1384387200  NaN
# 2                                       Smells awful      1376784000  NaN
# 3  Truth is There IS Nothing Like an AQUA VELVA MAN.      1304380800   25
# 4                                    Bvlgari Shampoo      1304640000    3
#
#   image   unixTime  Score
# 0   NaN 2016-09-01      1
# 1   NaN 2013-11-14      1
# 2   NaN 2013-08-18      0
# 3   NaN 2011-05-03      1
# 4   NaN 2011-05-06      1

# %%
df.shape
# Out:
# (9855, 14)

# %% [markdown]
# <div style="background-color:#202123; color:#ffffff; padding:8px 14px; border-radius:6px;">
#   <h2 style="margin:6px 0; color:#ffffff;">
#     3 Exploratory Data Analysis
#   </h2>
# </div>

# %%
df.head(1)
# Out:
#    overall  verified  reviewTime      reviewerID        asin  \
# 0      5.0      True  09 1, 2016  A3CIUOJXQ5VDQ2  B0000530HU
#
#                                                style reviewerName  \
# 0  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...     Shelly F
#
#                          reviewText     summary  unixReviewTime vote image  \
# 0  As advertised. Reasonably priced  Five Stars      1472688000  NaN   NaN
#
#     unixTime  Score
# 0 2016-09-01      1

# %%
sorted_df = df.sort_values(["reviewerName","reviewerID","unixTime","summary","reviewText"],ascending=True)

# %%
sorted_df.head(10)
# Out:
#       overall  verified   reviewTime      reviewerID        asin  \
# 4924      5.0     False  08 26, 2017  A2MJ8OL2FYN7CW  B00W259T7G
# 4187      5.0     False   09 4, 2017  A2MJ8OL2FYN7CW  B001LNODUS
# 5034      5.0     False   09 4, 2017  A2MJ8OL2FYN7CW  B019FWRG3C
# 4856      5.0     False  09 21, 2017  A2MJ8OL2FYN7CW  B00W259T7G
# 4849      5.0     False  09 27, 2017  A2MJ8OL2FYN7CW  B00W259T7G
# 4848      5.0     False  09 27, 2017  A2MJ8OL2FYN7CW  B00W259T7G
# 4160      4.0     False   08 2, 2016   ALNFHVS3SC4FV  B001ET7FZE
# 5056      4.0     False   08 2, 2016   ALNFHVS3SC4FV  B01BNEYGQU
# 4908      5.0     False  08 29, 2017   ALNFHVS3SC4FV  B00W259T7G
# 2190      5.0     False  09 10, 2017   ALNFHVS3SC4FV  B0010ZBORW
#
#                                                 style    reviewerName  \
# 4924   {'Size:': ' 250 Gram', 'Color:': ' Olive Oil'}        Lynne E.
# 4187                        {'Color:': ' Shower Gel'}        Lynne E.
# 5034                        {'Color:': ' Shower Gel'}        Lynne E.
# 4856    {'Size:': ' 150 Gram', 'Color:': ' Sea Salt'}        Lynne E.
# 4849  {'Size:': ' 250 Gram', 'Color:': ' Sandalwood'}        Lynne E.
# 4848   {'Size:': ' 250 Gram', 'Color:': ' Patchouli'}        Lynne E.
# 4160                 {'Style Name:': ' Bubble Fruit'}   Seas the Day
# 5056                 {'Style Name:': ' Bubble Fruit'}   Seas the Day
# 4908  {'Size:': ' 150 Gram', 'Color:': ' Starflower'}   Seas the Day
# 2190                            {'Color:': ' Loofah'}   Seas the Day
#
#                                              reviewText  \
# 4924  This PRE DE PROVENCE SHEA BUTTER ENRICHED ARTI...
# 4187  Lavender is my favorite soap fragrance, so it'...
# 5034  Lavender is my favorite soap fragrance, so it'...
# 4856  I love Pre de Provence soaps, but was intensel...
# 4849  This PRE DE PROVENCE Sandalwood SHEA BUTTER EN...
# 4848  This PRE DE PROVENCE PATCHOULI SHEA BUTTER ENR...
# 4160  My kids love using the Colgate pumps. I think ...
# 5056  My kids love using the Colgate pumps. I think ...
# 4908  Review for Starflower:\n\nThis is a nice bar o...
# 2190  Review for Loofah:\n\nI have tried loofahs in ...
#
#                                                 summary  unixReviewTime vote  \
# 4924    Feels Luxurious, Doesn't Dry Out Sensitive Skin      1503705600  NaN
# 4187  Clear Gel Creates Nice Lather With Delicate La...      1504483200  NaN
# 5034  Clear Gel Creates Nice Lather With Delicate La...      1504483200  NaN
# 4856  Luxurious French Soap Has Fresh Sea Breeze Fra...      1505952000    7
# 4849  Luxurious French Soap With Mild, Masculine Fra...      1506470400  NaN
# 4848  Luxurious French Soap With Musky Masculine Fra...      1506470400  NaN
# 4160                  Kids Like the Flavor and the Pump      1470096000  NaN
# 5056                  Kids Like the Flavor and the Pump      1470096000  NaN
# 4908      Large Bar, Floral but Nice and Clean Smelling      1503964800  NaN
# 2190              Nice Loofah with Attached Suction Cup      1505001600  NaN
#
#      image   unixTime  Score
# 4924   NaN 2017-08-26      1
# 4187   NaN 2017-09-04      1
# 5034   NaN 2017-09-04      1
# 4856   NaN 2017-09-21      1
# 4849   NaN 2017-09-27      1
# 4848   NaN 2017-09-27      1
# 4160   NaN 2016-08-02      1
# 5056   NaN 2016-08-02      1
# 4908   NaN 2017-08-29      1
# 2190   NaN 2017-09-10      1

# %%
sorted_df.shape
# Out:
# (9855, 14)

# %%
sorted_df.drop_duplicates(subset=["reviewerName","reviewerID","unixTime","summary","reviewText"],inplace=True)

# %%
sorted_df.shape
# Out:
# (1874, 14)

# %%
sorted_df.head()
# Out:
#       overall  verified   reviewTime      reviewerID        asin  \
# 4924      5.0     False  08 26, 2017  A2MJ8OL2FYN7CW  B00W259T7G
# 4187      5.0     False   09 4, 2017  A2MJ8OL2FYN7CW  B001LNODUS
# 4856      5.0     False  09 21, 2017  A2MJ8OL2FYN7CW  B00W259T7G
# 4849      5.0     False  09 27, 2017  A2MJ8OL2FYN7CW  B00W259T7G
# 4848      5.0     False  09 27, 2017  A2MJ8OL2FYN7CW  B00W259T7G
#
#                                                 style reviewerName  \
# 4924   {'Size:': ' 250 Gram', 'Color:': ' Olive Oil'}     Lynne E.
# 4187                        {'Color:': ' Shower Gel'}     Lynne E.
# 4856    {'Size:': ' 150 Gram', 'Color:': ' Sea Salt'}     Lynne E.
# 4849  {'Size:': ' 250 Gram', 'Color:': ' Sandalwood'}     Lynne E.
# 4848   {'Size:': ' 250 Gram', 'Color:': ' Patchouli'}     Lynne E.
#
#                                              reviewText  \
# 4924  This PRE DE PROVENCE SHEA BUTTER ENRICHED ARTI...
# 4187  Lavender is my favorite soap fragrance, so it'...
# 4856  I love Pre de Provence soaps, but was intensel...
# 4849  This PRE DE PROVENCE Sandalwood SHEA BUTTER EN...
# 4848  This PRE DE PROVENCE PATCHOULI SHEA BUTTER ENR...
#
#                                                 summary  unixReviewTime vote  \
# 4924    Feels Luxurious, Doesn't Dry Out Sensitive Skin      1503705600  NaN
# 4187  Clear Gel Creates Nice Lather With Delicate La...      1504483200  NaN
# 4856  Luxurious French Soap Has Fresh Sea Breeze Fra...      1505952000    7
# 4849  Luxurious French Soap With Mild, Masculine Fra...      1506470400  NaN
# 4848  Luxurious French Soap With Musky Masculine Fra...      1506470400  NaN
#
#      image   unixTime  Score
# 4924   NaN 2017-08-26      1
# 4187   NaN 2017-09-04      1
# 4856   NaN 2017-09-21      1
# 4849   NaN 2017-09-27      1
# 4848   NaN 2017-09-27      1

# %% [markdown]
# <h2>Display full text</h2>

# %%
pd.set_option("display.max_columns",100)
pd.set_option("display.max_rows",100)

# %%
text=[]
text = [txt for txt in sorted_df['reviewText'].head(10)]

# %%
for txt in text:
  with open(r"text/txt",'a+') as f:
    f.write(txt)

# %%
with open(r"text/txt",'r+') as f:
    content=f.read()
    print(content)
# Out:
# This PRE DE PROVENCE SHEA BUTTER ENRICHED ARTISANAL FRENCH SOAP BAR (Olive Oil (250 g)) lathers beautifully, and feels luxurious.  It doesn't dry out or irritate my sensitive skin, so I can use it every day.  This is a large 250 gram olive oil bar that gives good value for the money (about $7 on Amazon).Lavender is my favorite soap fragrance, so it's no surprise that I love this PRE DE PROVENCE FRENCH LAVENDER BATH & SHOWER GEL.  For the shower, a pump or two is enough for a nice lather, and the lather washes off easily.
#
# The lavender fragrance is delicate, and it lingers for only a short time.  It doesn't overwhelm perfume, aftershave lotion, shampoo, or other scented products you may like to use.  The clear gel arrives in an attractive square pump dispenser.
#
# The shower gel leaves my skin silky smooth, and it doesn't irritate my sensitive skin.I love Pre de Provence soaps, but was intensely curious about the Sea Salt bar.  What would it smell like?  Why would I want to wash my hands with sea salt?  Happily, this PRE DE PROVENCE SEA SALT FRENCH SOAP BAR (150g, 5.2 Ounce) is no different from the other Pre de Provence soaps--it smells wonderful, and produces a rich, thick lather.
#
# The fragrance is hard to describe.  Its kind of floral, but maybe is best described as fresh sea breeze.  It makes one think of fresh air and sunshine.  The fragrance doesn't linger overlong.  The soap doesn't irritate my sensitive skin, but may be a little more drying than other Pre de Provence soaps (unless it's my imagination working overtime).
#
# The soap definitely contains salt. The ingredients are:  sodium palmate, sodium palm kernelate, water, fragrance, palm acid, titanium dioxide, glycerin, palm kernel acid, SODIUM CHLORIDE, shea butter, sodium hydroxide, tetrasodium edta, tetrasodium etidronate, benzyl salicylate, linalool, geraniol, citral.This PRE DE PROVENCE Sandalwood SHEA BUTTER ENRICHED SOAP (250 Gram) should appeal to the male members of the household, because of the mild, woody fragrance.  (Most Pre de Provence soaps have fairly strong, flowery fragrances.)
#
# It's a large bar of luxurious French soap.  It lathers beautifully, and the fragrance never lingers too long.  The soap is very gentle, and doesn't irritate sensitive skin.This PRE DE PROVENCE PATCHOULI SHEA BUTTER ENRICHED SOAP (250 Gram) has the mild, musky fragrance that many women find sexy, but the fragrance is risky.  To some people (including me) it smells like fungus or damp basement.  Still, this soap may appeal to male household members, because it's so different from most other Pre de Provence soaps (with their fairly strong, flowery fragrances).
#
# This is a large bar of luxurious French soap.  It lathers beautifully, and the fragrance never lingers too long.  The soap is very gentle, and doesn't irritate sensitive skin.
#
# For men, a much safer Pre de Provence soap is the Sandalwood bar (see&nbsp;<a data-hook="product-link-linked" class="a-link-normal" href="/Pre-de-Provence-Sandalwood/dp/B01LWWOLW2/ref=cm_cr_arp_d_rvw_txt?ie=UTF8">Pre de Provence Sandalwood</a>).My kids love using the Colgate pumps. I think it just seems fun to them and they are easier for kids to operate than having to squeeze tubes. I do feel like the pumps leave a little bit left in the bottom though so you get a little bit less product with them. The pumps are definitely less messy though.
#
# Our order came as 6 pumps of Colgate Maximum Cavity Protection in mild bubble fruit flavor. The toothpaste is a blue gel. Its slightly fruity but still minty. All 6 pumps had an expiration date of 10/2017 (this is 8/2016) so the expiration date is over a year out - plenty of time to use all 6 pumps. All the pumps have a safety seal on the pump that has to be broken off so you know they are sealed and safe.
#
# The kids really like this flavor and the pump.Review for Starflower:
#
# This is a nice bar of soap. It has a hard consistency, not a soft bar so it seems to last longer. The soap provides a lot of suds which makes you feel like you are getting clean. It is a large size too which my husband really loves.
#
# I had never smelled starflower before. The scent of the soap is a floral but not in a heavy or sweet type scent, it smells nothing like roses or magnolias but is just clean floral scent. Im not a big fan of florals and this one is ok, my husband doesnt care for anything girly scented and he doesnt mind this one either.Review for Loofah:
#
# I have tried loofahs in the past and was never a big fan but I gave the Urban Spa Loofah a try and Im glad that I did. The loofah arrives a little flat from packaging but swells up nice and round in the water. It is surprisingly soft in the water. It works great with body wash providing lots of suds.
#
# I like that it has an attached ribbon and suction cup. I thought that the suction cup being attached would bother me as I used it but it has not. Its nice that I can hang it on my shower door. It attaches securely and I haven't had any trouble with it slipping or sliding on the glass.Have used for a long time and nothing has worked better. This is a winner and I will continue to purchase it.This is my favorite floss.  I do feel like my teeth are much cleaner when I use it.  Like the name says, it glides easily between my teeth, no sticking or shredding.  The plastic container is small, compact and attractive.  The minty flavor is a nice touch.This PRE DE PROVENCE SHEA BUTTER ENRICHED ARTISANAL FRENCH SOAP BAR (Olive Oil (250 g)) lathers beautifully, and feels luxurious.  It doesn't dry out or irritate my sensitive skin, so I can use it every day.  This is a large 250 gram olive oil bar that gives good value for the money (about $7 on Amazon).Lavender is my favorite soap fragrance, so it's no surprise that I love this PRE DE PROVENCE FRENCH LAVENDER BATH & SHOWER GEL.  For the shower, a pump or two is enough for a nice lather, and the lather washes off easily.
#
# The lavender fragrance is delicate, and it lingers for only a short time.  It doesn't overwhelm perfume, aftershave lotion, shampoo, or other scented products you may like to use.  The clear gel arrives in an attractive square pump dispenser.
#
# The shower gel leaves my skin silky smooth, and it doesn't irritate my sensitive skin.I love Pre de Provence soaps, but was intensely curious about the Sea Salt bar.  What would it smell like?  Why would I want to wash my hands with sea salt?  Happily, this PRE DE PROVENCE SEA SALT FRENCH SOAP BAR (150g, 5.2 Ounce) is no different from the other Pre de Provence soaps--it smells wonderful, and produces a rich, thick lather.
#
# The fragrance is hard to describe.  Its kind of floral, but maybe is best described as fresh sea breeze.  It makes one think of fresh air and sunshine.  The fragrance doesn't linger overlong.  The soap doesn't irritate my sensitive skin, but may be a little more drying than other Pre de Provence soaps (unless it's my imagination working overtime).
#
# The soap definitely contains salt. The ingredients are:  sodium palmate, sodium palm kernelate, water, fragrance, palm acid, titanium dioxide, glycerin, palm kernel acid, SODIUM CHLORIDE, shea butter, sodium hydroxide, tetrasodium edta, tetrasodium etidronate, benzyl salicylate, linalool, geraniol, citral.This PRE DE PROVENCE Sandalwood SHEA BUTTER ENRICHED SOAP (250 Gram) should appeal to the male members of the household, because of the mild, woody fragrance.  (Most Pre de Provence soaps have fairly strong, flowery fragrances.)
#
# It's a large bar of luxurious French soap.  It lathers beautifully, and the fragrance never lingers too long.  The soap is very gentle, and doesn't irritate sensitive skin.This PRE DE PROVENCE PATCHOULI SHEA BUTTER ENRICHED SOAP (250 Gram) has the mild, musky fragrance that many women find sexy, but the fragrance is risky.  To some people (including me) it smells like fungus or damp basement.  Still, this soap may appeal to male household members, because it's so different from most other Pre de Provence soaps (with their fairly strong, flowery fragrances).
#
# This is a large bar of luxurious French soap.  It lathers beautifully, and the fragrance never lingers too long.  The soap is very gentle, and doesn't irritate sensitive skin.
#
# For men, a much safer Pre de Provence soap is the Sandalwood bar (see&nbsp;<a data-hook="product-link-linked" class="a-link-normal" href="/Pre-de-Provence-Sandalwood/dp/B01LWWOLW2/ref=cm_cr_arp_d_rvw_txt?ie=UTF8">Pre de Provence Sandalwood</a>).My kids love using the Colgate pumps. I think it just seems fun to them and they are easier for kids to operate than having to squeeze tubes. I do feel like the pumps leave a little bit left in the bottom though so you get a little bit less product with them. The pumps are definitely less messy though.
#
# Our order came as 6 pumps of Colgate Maximum Cavity Protection in mild bubble fruit flavor. The toothpaste is a blue gel. Its slightly fruity but still minty. All 6 pumps had an expiration date of 10/2017 (this is 8/2016) so the expiration date is over a year out - plenty of time to use all 6 pumps. All the pumps have a safety seal on the pump that has to be broken off so you know they are sealed and safe.
#
# The kids really like this flavor and the pump.Review for Starflower:
#
# This is a nice bar of soap. It has a hard consistency, not a soft bar so it seems to last longer. The soap provides a lot of suds which makes you feel like you are getting clean. It is a large size too which my husband really loves.
#
# I had never smelled starflower before. The scent of the soap is a floral but not in a heavy or sweet type scent, it smells nothing like roses or magnolias but is just clean floral scent. Im not a big fan of florals and this one is ok, my husband doesnt care for anything girly scented and he doesnt mind this one either.Review for Loofah:
#
# I have tried loofahs in the past and was never a big fan but I gave the Urban Spa Loofah a try and Im glad that I did. The loofah arrives a little flat from packaging but swells up nice and round in the water. It is surprisingly soft in the water. It works great with body wash providing lots of suds.
#
# I like that it has an attached ribbon and suction cup. I thought that the suction cup being attached would bother me as I used it but it has not. Its nice that I can hang it on my shower door. It attaches securely and I haven't had any trouble with it slipping or sliding on the glass.Have used for a long time and nothing has worked better. This is a winner and I will continue to purchase it.This is my favorite floss.  I do feel like my teeth are much cleaner when I use it.  Like the name says, it glides easily between my teeth, no sticking or shredding.  The plastic container is small, compact and attractive.  The minty flavor is a nice touch.This PRE DE PROVENCE SHEA BUTTER ENRICHED ARTISANAL FRENCH SOAP BAR (Olive Oil (250 g)) lathers beautifully, and feels luxurious.  It doesn't dry out or irritate my sensitive skin, so I can use it every day.  This is a large 250 gram olive oil bar that gives good value for the money (about $7 on Amazon).Lavender is my favorite soap fragrance, so it's no surprise that I love this PRE DE PROVENCE FRENCH LAVENDER BATH & SHOWER GEL.  For the shower, a pump or two is enough for a nice lather, and the lather washes off easily.
#
# The lavender fragrance is delicate, and it lingers for only a short time.  It doesn't overwhelm perfume, aftershave lotion, shampoo, or other scented products you may like to use.  The clear gel arrives in an attractive square pump dispenser.
#
# The shower gel leaves my skin silky smooth, and it doesn't irritate my sensitive skin.I love Pre de Provence soaps, but was intensely curious about the Sea Salt bar.  What would it smell like?  Why would I want to wash my hands with sea salt?  Happily, this PRE DE PROVENCE SEA SALT FRENCH SOAP BAR (150g, 5.2 Ounce) is no different from the other Pre de Provence soaps--it smells wonderful, and produces a rich, thick lather.
#
# The fragrance is hard to describe.  Its kind of floral, but maybe is best described as fresh sea breeze.  It makes one think of fresh air and sunshine.  The fragrance doesn't linger overlong.  The soap doesn't irritate my sensitive skin, but may be a little more drying than other Pre de Provence soaps (unless it's my imagination working overtime).
#
# The soap definitely contains salt. The ingredients are:  sodium palmate, sodium palm kernelate, water, fragrance, palm acid, titanium dioxide, glycerin, palm kernel acid, SODIUM CHLORIDE, shea butter, sodium hydroxide, tetrasodium edta, tetrasodium etidronate, benzyl salicylate, linalool, geraniol, citral.This PRE DE PROVENCE Sandalwood SHEA BUTTER ENRICHED SOAP (250 Gram) should appeal to the male members of the household, because of the mild, woody fragrance.  (Most Pre de Provence soaps have fairly strong, flowery fragrances.)
#
# It's a large bar of luxurious French soap.  It lathers beautifully, and the fragrance never lingers too long.  The soap is very gentle, and doesn't irritate sensitive skin.This PRE DE PROVENCE PATCHOULI SHEA BUTTER ENRICHED SOAP (250 Gram) has the mild, musky fragrance that many women find sexy, but the fragrance is risky.  To some people (including me) it smells like fungus or damp basement.  Still, this soap may appeal to male household members, because it's so different from most other Pre de Provence soaps (with their fairly strong, flowery fragrances).
#
# This is a large bar of luxurious French soap.  It lathers beautifully, and the fragrance never lingers too long.  The soap is very gentle, and doesn't irritate sensitive skin.
#
# For men, a much safer Pre de Provence soap is the Sandalwood bar (see&nbsp;<a data-hook="product-link-linked" class="a-link-normal" href="/Pre-de-Provence-Sandalwood/dp/B01LWWOLW2/ref=cm_cr_arp_d_rvw_txt?ie=UTF8">Pre de Provence Sandalwood</a>).My kids love using the Colgate pumps. I think it just seems fun to them and they are easier for kids to operate than having to squeeze tubes. I do feel like the pumps leave a little bit left in the bottom though so you get a little bit less product with them. The pumps are definitely less messy though.
#
# Our order came as 6 pumps of Colgate Maximum Cavity Protection in mild bubble fruit flavor. The toothpaste is a blue gel. Its slightly fruity but still minty. All 6 pumps had an expiration date of 10/2017 (this is 8/2016) so the expiration date is over a year out - plenty of time to use all 6 pumps. All the pumps have a safety seal on the pump that has to be broken off so you know they are sealed and safe.
#
# The kids really like this flavor and the pump.Review for Starflower:
#
# This is a nice bar of soap. It has a hard consistency, not a soft bar so it seems to last longer. The soap provides a lot of suds which makes you feel like you are getting clean. It is a large size too which my husband really loves.
#
# I had never smelled starflower before. The scent of the soap is a floral but not in a heavy or sweet type scent, it smells nothing like roses or magnolias but is just clean floral scent. Im not a big fan of florals and this one is ok, my husband doesnt care for anything girly scented and he doesnt mind this one either.Review for Loofah:
#
# I have tried loofahs in the past and was never a big fan but I gave the Urban Spa Loofah a try and Im glad that I did. The loofah arrives a little flat from packaging but swells up nice and round in the water. It is surprisingly soft in the water. It works great with body wash providing lots of suds.
#
# I like that it has an attached ribbon and suction cup. I thought that the suction cup being attached would bother me as I used it but it has not. Its nice that I can hang it on my shower door. It attaches securely and I haven't had any trouble with it slipping or sliding on the glass.Have used for a long time and nothing has worked better. This is a winner and I will continue to purchase it.This is my favorite floss.  I do feel like my teeth are much cleaner when I use it.  Like the name says, it glides easily between my teeth, no sticking or shredding.  The plastic container is small, compact and attractive.  The minty flavor is a nice touch.This PRE DE PROVENCE SHEA BUTTER ENRICHED ARTISANAL FRENCH SOAP BAR (Olive Oil (250 g)) lathers beautifully, and feels luxurious.  It doesn't dry out or irritate my sensitive skin, so I can use it every day.  This is a large 250 gram olive oil bar that gives good value for the money (about $7 on Amazon).Lavender is my favorite soap fragrance, so it's no surprise that I love this PRE DE PROVENCE FRENCH LAVENDER BATH & SHOWER GEL.  For the shower, a pump or two is enough for a nice lather, and the lather washes off easily.
#
# The lavender fragrance is delicate, and it lingers for only a short time.  It doesn't overwhelm perfume, aftershave lotion, shampoo, or other scented products you may like to use.  The clear gel arrives in an attractive square pump dispenser.
#
# The shower gel leaves my skin silky smooth, and it doesn't irritate my sensitive skin.I love Pre de Provence soaps, but was intensely curious about the Sea Salt bar.  What would it smell like?  Why would I want to wash my hands with sea salt?  Happily, this PRE DE PROVENCE SEA SALT FRENCH SOAP BAR (150g, 5.2 Ounce) is no different from the other Pre de Provence soaps--it smells wonderful, and produces a rich, thick lather.
#
# The fragrance is hard to describe.  Its kind of floral, but maybe is best described as fresh sea breeze.  It makes one think of fresh air and sunshine.  The fragrance doesn't linger overlong.  The soap doesn't irritate my sensitive skin, but may be a little more drying than other Pre de Provence soaps (unless it's my imagination working overtime).
#
# The soap definitely contains salt. The ingredients are:  sodium palmate, sodium palm kernelate, water, fragrance, palm acid, titanium dioxide, glycerin, palm kernel acid, SODIUM CHLORIDE, shea butter, sodium hydroxide, tetrasodium edta, tetrasodium etidronate, benzyl salicylate, linalool, geraniol, citral.This PRE DE PROVENCE Sandalwood SHEA BUTTER ENRICHED SOAP (250 Gram) should appeal to the male members of the household, because of the mild, woody fragrance.  (Most Pre de Provence soaps have fairly strong, flowery fragrances.)
#
# It's a large bar of luxurious French soap.  It lathers beautifully, and the fragrance never lingers too long.  The soap is very gentle, and doesn't irritate sensitive skin.This PRE DE PROVENCE PATCHOULI SHEA BUTTER ENRICHED SOAP (250 Gram) has the mild, musky fragrance that many women find sexy, but the fragrance is risky.  To some people (including me) it smells like fungus or damp basement.  Still, this soap may appeal to male household members, because it's so different from most other Pre de Provence soaps (with their fairly strong, flowery fragrances).
#
# This is a large bar of luxurious French soap.  It lathers beautifully, and the fragrance never lingers too long.  The soap is very gentle, and doesn't irritate sensitive skin.
#
# For men, a much safer Pre de Provence soap is the Sandalwood bar (see&nbsp;<a data-hook="product-link-linked" class="a-link-normal" href="/Pre-de-Provence-Sandalwood/dp/B01LWWOLW2/ref=cm_cr_arp_d_rvw_txt?ie=UTF8">Pre de Provence Sandalwood</a>).My kids love using the Colgate pumps. I think it just seems fun to them and they are easier for kids to operate than having to squeeze tubes. I do feel like the pumps leave a little bit left in the bottom though so you get a little bit less product with them. The pumps are definitely less messy though.
#
# Our order came as 6 pumps of Colgate Maximum Cavity Protection in mild bubble fruit flavor. The toothpaste is a blue gel. Its slightly fruity but still minty. All 6 pumps had an expiration date of 10/2017 (this is 8/2016) so the expiration date is over a year out - plenty of time to use all 6 pumps. All the pumps have a safety seal on the pump that has to be broken off so you know they are sealed and safe.
#
# The kids really like this flavor and the pump.Review for Starflower:
#
# This is a nice bar of soap. It has a hard consistency, not a soft bar so it seems to last longer. The soap provides a lot of suds which makes you feel like you are getting clean. It is a large size too which my husband really loves.
#
# I had never smelled starflower before. The scent of the soap is a floral but not in a heavy or sweet type scent, it smells nothing like roses or magnolias but is just clean floral scent. Im not a big fan of florals and this one is ok, my husband doesnt care for anything girly scented and he doesnt mind this one either.Review for Loofah:
#
# I have tried loofahs in the past and was never a big fan but I gave the Urban Spa Loofah a try and Im glad that I did. The loofah arrives a little flat from packaging but swells up nice and round in the water. It is surprisingly soft in the water. It works great with body wash providing lots of suds.
#
# I like that it has an attached ribbon and suction cup. I thought that the suction cup being attached would bother me as I used it but it has not. Its nice that I can hang it on my shower door. It attaches securely and I haven't had any trouble with it slipping or sliding on the glass.Have used for a long time and nothing has worked better. This is a winner and I will continue to purchase it.This is my favorite floss.  I do feel like my teeth are much cleaner when I use it.  Like the name says, it glides easily between my teeth, no sticking or shredding.  The plastic container is small, compact and attractive.  The minty flavor is a nice touch.This PRE DE PROVENCE SHEA BUTTER ENRICHED ARTISANAL FRENCH SOAP BAR (Olive Oil (250 g)) lathers beautifully, and feels luxurious.  It doesn't dry out or irritate my sensitive skin, so I can use it every day.  This is a large 250 gram olive oil bar that gives good value for the money (about $7 on Amazon).Lavender is my favorite soap fragrance, so it's no surprise that I love this PRE DE PROVENCE FRENCH LAVENDER BATH & SHOWER GEL.  For the shower, a pump or two is enough for a nice lather, and the lather washes off easily.
#
# The lavender fragrance is delicate, and it lingers for only a short time.  It doesn't overwhelm perfume, aftershave lotion, shampoo, or other scented products you may like to use.  The clear gel arrives in an attractive square pump dispenser.
#
# The shower gel leaves my skin silky smooth, and it doesn't irritate my sensitive skin.I love Pre de Provence soaps, but was intensely curious about the Sea Salt bar.  What would it smell like?  Why would I want to wash my hands with sea salt?  Happily, this PRE DE PROVENCE SEA SALT FRENCH SOAP BAR (150g, 5.2 Ounce) is no different from the other Pre de Provence soaps--it smells wonderful, and produces a rich, thick lather.
#
# The fragrance is hard to describe.  Its kind of floral, but maybe is best described as fresh sea breeze.  It makes one think of fresh air and sunshine.  The fragrance doesn't linger overlong.  The soap doesn't irritate my sensitive skin, but may be a little more drying than other Pre de Provence soaps (unless it's my imagination working overtime).
#
# The soap definitely contains salt. The ingredients are:  sodium palmate, sodium palm kernelate, water, fragrance, palm acid, titanium dioxide, glycerin, palm kernel acid, SODIUM CHLORIDE, shea butter, sodium hydroxide, tetrasodium edta, tetrasodium etidronate, benzyl salicylate, linalool, geraniol, citral.This PRE DE PROVENCE Sandalwood SHEA BUTTER ENRICHED SOAP (250 Gram) should appeal to the male members of the household, because of the mild, woody fragrance.  (Most Pre de Provence soaps have fairly strong, flowery fragrances.)
#
# It's a large bar of luxurious French soap.  It lathers beautifully, and the fragrance never lingers too long.  The soap is very gentle, and doesn't irritate sensitive skin.This PRE DE PROVENCE PATCHOULI SHEA BUTTER ENRICHED SOAP (250 Gram) has the mild, musky fragrance that many women find sexy, but the fragrance is risky.  To some people (including me) it smells like fungus or damp basement.  Still, this soap may appeal to male household members, because it's so different from most other Pre de Provence soaps (with their fairly strong, flowery fragrances).
#
# This is a large bar of luxurious French soap.  It lathers beautifully, and the fragrance never lingers too long.  The soap is very gentle, and doesn't irritate sensitive skin.
#
# For men, a much safer Pre de Provence soap is the Sandalwood bar (see&nbsp;<a data-hook="product-link-linked" class="a-link-normal" href="/Pre-de-Provence-Sandalwood/dp/B01LWWOLW2/ref=cm_cr_arp_d_rvw_txt?ie=UTF8">Pre de Provence Sandalwood</a>).My kids love using the Colgate pumps. I think it just seems fun to them and they are easier for kids to operate than having to squeeze tubes. I do feel like the pumps leave a little bit left in the bottom though so you get a little bit less product with them. The pumps are definitely less messy though.
#
# Our order came as 6 pumps of Colgate Maximum Cavity Protection in mild bubble fruit flavor. The toothpaste is a blue gel. Its slightly fruity but still minty. All 6 pumps had an expiration date of 10/2017 (this is 8/2016) so the expiration date is over a year out - plenty of time to use all 6 pumps. All the pumps have a safety seal on the pump that has to be broken off so you know they are sealed and safe.
#
# The kids really like this flavor and the pump.Review for Starflower:
#
# This is a nice bar of soap. It has a hard consistency, not a soft bar so it seems to last longer. The soap provides a lot of suds which makes you feel like you are getting clean. It is a large size too which my husband really loves.
#
# I had never smelled starflower before. The scent of the soap is a floral but not in a heavy or sweet type scent, it smells nothing like roses or magnolias but is just clean floral scent. Im not a big fan of florals and this one is ok, my husband doesnt care for anything girly scented and he doesnt mind this one either.Review for Loofah:
#
# I have tried loofahs in the past and was never a big fan but I gave the Urban Spa Loofah a try and Im glad that I did. The loofah arrives a little flat from packaging but swells up nice and round in the water. It is surprisingly soft in the water. It works great with body wash providing lots of suds.
#
# I like that it has an attached ribbon and suction cup. I thought that the suction cup being attached would bother me as I used it but it has not. Its nice that I can hang it on my shower door. It attaches securely and I haven't had any trouble with it slipping or sliding on the glass.Have used for a long time and nothing has worked better. This is a winner and I will continue to purchase it.This is my favorite floss.  I do feel like my teeth are much cleaner when I use it.  Like the name says, it glides easily between my teeth, no sticking or shredding.  The plastic container is small, compact and attractive.  The minty flavor is a nice touch.This PRE DE PROVENCE SHEA BUTTER ENRICHED ARTISANAL FRENCH SOAP BAR (Olive Oil (250 g)) lathers beautifully, and feels luxurious.  It doesn't dry out or irritate my sensitive skin, so I can use it every day.  This is a large 250 gram olive oil bar that gives good value for the money (about $7 on Amazon).Lavender is my favorite soap fragrance, so it's no surprise that I love this PRE DE PROVENCE FRENCH LAVENDER BATH & SHOWER GEL.  For the shower, a pump or two is enough for a nice lather, and the lather washes off easily.
#
# The lavender fragrance is delicate, and it lingers for only a short time.  It doesn't overwhelm perfume, aftershave lotion, shampoo, or other scented products you may like to use.  The clear gel arrives in an attractive square pump dispenser.
#
# The shower gel leaves my skin silky smooth, and it doesn't irritate my sensitive skin.I love Pre de Provence soaps, but was intensely curious about the Sea Salt bar.  What would it smell like?  Why would I want to wash my hands with sea salt?  Happily, this PRE DE PROVENCE SEA SALT FRENCH SOAP BAR (150g, 5.2 Ounce) is no different from the other Pre de Provence soaps--it smells wonderful, and produces a rich, thick lather.
#
# The fragrance is hard to describe.  Its kind of floral, but maybe is best described as fresh sea breeze.  It makes one think of fresh air and sunshine.  The fragrance doesn't linger overlong.  The soap doesn't irritate my sensitive skin, but may be a little more drying than other Pre de Provence soaps (unless it's my imagination working overtime).
#
# The soap definitely contains salt. The ingredients are:  sodium palmate, sodium palm kernelate, water, fragrance, palm acid, titanium dioxide, glycerin, palm kernel acid, SODIUM CHLORIDE, shea butter, sodium hydroxide, tetrasodium edta, tetrasodium etidronate, benzyl salicylate, linalool, geraniol, citral.This PRE DE PROVENCE Sandalwood SHEA BUTTER ENRICHED SOAP (250 Gram) should appeal to the male members of the household, because of the mild, woody fragrance.  (Most Pre de Provence soaps have fairly strong, flowery fragrances.)
#
# It's a large bar of luxurious French soap.  It lathers beautifully, and the fragrance never lingers too long.  The soap is very gentle, and doesn't irritate sensitive skin.This PRE DE PROVENCE PATCHOULI SHEA BUTTER ENRICHED SOAP (250 Gram) has the mild, musky fragrance that many women find sexy, but the fragrance is risky.  To some people (including me) it smells like fungus or damp basement.  Still, this soap may appeal to male household members, because it's so different from most other Pre de Provence soaps (with their fairly strong, flowery fragrances).
#
# This is a large bar of luxurious French soap.  It lathers beautifully, and the fragrance never lingers too long.  The soap is very gentle, and doesn't irritate sensitive skin.
#
# For men, a much safer Pre de Provence soap is the Sandalwood bar (see&nbsp;<a data-hook="product-link-linked" class="a-link-normal" href="/Pre-de-Provence-Sandalwood/dp/B01LWWOLW2/ref=cm_cr_arp_d_rvw_txt?ie=UTF8">Pre de Provence Sandalwood</a>).My kids love using the Colgate pumps. I think it just seems fun to them and they are easier for kids to operate than having to squeeze tubes. I do feel like the pumps leave a little bit left in the bottom though so you get a little bit less product with them. The pumps are definitely less messy though.
#
# Our order came as 6 pumps of Colgate Maximum Cavity Protection in mild bubble fruit flavor. The toothpaste is a blue gel. Its slightly fruity but still minty. All 6 pumps had an expiration date of 10/2017 (this is 8/2016) so the expiration date is over a year out - plenty of time to use all 6 pumps. All the pumps have a safety seal on the pump that has to be broken off so you know they are sealed and safe.
#
# The kids really like this flavor and the pump.Review for Starflower:
#
# This is a nice bar of soap. It has a hard consistency, not a soft bar so it seems to last longer. The soap provides a lot of suds which makes you feel like you are getting clean. It is a large size too which my husband really loves.
#
# I had never smelled starflower before. The scent of the soap is a floral but not in a heavy or sweet type scent, it smells nothing like roses or magnolias but is just clean floral scent. Im not a big fan of florals and this one is ok, my husband doesnt care for anything girly scented and he doesnt mind this one either.Review for Loofah:
#
# I have tried loofahs in the past and was never a big fan but I gave the Urban Spa Loofah a try and Im glad that I did. The loofah arrives a little flat from packaging but swells up nice and round in the water. It is surprisingly soft in the water. It works great with body wash providing lots of suds.
#
# I like that it has an attached ribbon and suction cup. I thought that the suction cup being attached would bother me as I used it but it has not. Its nice that I can hang it on my shower door. It attaches securely and I haven't had any trouble with it slipping or sliding on the glass.Have used for a long time and nothing has worked better. This is a winner and I will continue to purchase it.This is my favorite floss.  I do feel like my teeth are much cleaner when I use it.  Like the name says, it glides easily between my teeth, no sticking or shredding.  The plastic container is small, compact and attractive.  The minty flavor is a nice touch.

# %% [markdown]
# <div style="background-color:#202123; color:#ffffff; padding:8px 14px; border-radius:6px;">
#   <h2 style="margin:6px 0; color:#ffffff;">
#     4 Preprocessing the data
#   </h2>
# </div>

# %% [markdown]
# __Remove URL__

# %%
s1 = print(sorted_df['reviewText'].values[0])
# Out:
# This PRE DE PROVENCE SHEA BUTTER ENRICHED ARTISANAL FRENCH SOAP BAR (Olive Oil (250 g)) lathers beautifully, and feels luxurious.  It doesn't dry out or irritate my sensitive skin, so I can use it every day.  This is a large 250 gram olive oil bar that gives good value for the money (about $7 on Amazon).

# %%
sorted_df['reviewText'] = sorted_df['reviewText'].astype('string').apply(lambda x : re.sub(r"http\S+","",x) if x is not pd.NA else x)

# %%
sorted_df['reviewText']
# Out:
# 4924    This PRE DE PROVENCE SHEA BUTTER ENRICHED ARTI...
# 4187    Lavender is my favorite soap fragrance, so it'...
# 4856    I love Pre de Provence soaps, but was intensel...
# 4849    This PRE DE PROVENCE Sandalwood SHEA BUTTER EN...
# 4848    This PRE DE PROVENCE PATCHOULI SHEA BUTTER ENR...
#                               ...
# 3130    Size, colour and print all above average but d...
# 816     Great product - kids love it and it smells goo...
# 405     extremely pleased, very pleasant scent, very l...
# 643                                           My favorite
# 606               Very good product----I use it every day
# Name: reviewText, Length: 1874, dtype: str

# %% [markdown]
# <h2>Using Beutifulsoup</h2>

# %%
from bs4 import BeautifulSoup

# %%
bs = [BeautifulSoup(text,'lxml').get_text() if pd.notna(text) else text for text in sorted_df['reviewText'] ]

# %%
sorted_df.loc[:,'Text']=bs

# %%
sorted_df['reviewText']=sorted_df['Text']

# %%
sorted_df.drop(columns=['Text'],inplace=True)

# %%
sorted_df.head(1)
# Out:
#       overall  verified   reviewTime      reviewerID        asin  \
# 4924      5.0     False  08 26, 2017  A2MJ8OL2FYN7CW  B00W259T7G
#
#                                                style reviewerName  \
# 4924  {'Size:': ' 250 Gram', 'Color:': ' Olive Oil'}     Lynne E.
#
#                                              reviewText  \
# 4924  This PRE DE PROVENCE SHEA BUTTER ENRICHED ARTI...
#
#                                               summary  unixReviewTime vote  \
# 4924  Feels Luxurious, Doesn't Dry Out Sensitive Skin      1503705600  NaN
#
#      image   unixTime  Score
# 4924   NaN 2017-08-26      1

# %% [markdown]
# <h2>Expand the word</h2>

# %%
def expand(phrase):
    phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

# %%
sorted_df["reviewText"] = sorted_df["reviewText"].apply(lambda x:expand(x) if pd.notna(x) else x)

# %%
sorted_df["reviewText"].values[1]
# Out:
# 'Lavender is my favorite soap fragrance, so it is no surprise that I love this PRE DE PROVENCE FRENCH LAVENDER BATH & SHOWER GEL.  For the shower, a pump or two is enough for a nice lather, and the lather washes off easily.\n\nThe lavender fragrance is delicate, and it lingers for only a short time.  It does not overwhelm perfume, aftershave lotion, shampoo, or other scented products you may like to use.  The clear gel arrives in an attractive square pump dispenser.\n\nThe shower gel leaves my skin silky smooth, and it does not irritate my sensitive skin.'

# %% [markdown]
# __remove space with number__

# %%
sorted_df["reviewText"].apply(lambda x: re.sub(r'\S*\d\S*',"",x) if pd.notna(x) else pd.NA)
# Out:
# 4924    This PRE DE PROVENCE SHEA BUTTER ENRICHED ARTI...
# 4187    Lavender is my favorite soap fragrance, so it ...
# 4856    I love Pre de Provence soaps, but was intensel...
# 4849    This PRE DE PROVENCE Sandalwood SHEA BUTTER EN...
# 4848    This PRE DE PROVENCE PATCHOULI SHEA BUTTER ENR...
#                               ...
# 3130    Size, colour and print all above average but d...
# 816     Great product - kids love it and it smells goo...
# 405     extremely pleased, very pleasant scent, very l...
# 643                                           My favorite
# 606               Very good product----I use it every day
# Name: reviewText, Length: 1874, dtype: str

# %% [markdown]
# __Removing special character__

# %%
sorted_df["reviewText"].apply(lambda x: re.sub(r'[^a-zA-Z0-9]+',"",x) if pd.notna(x) else pd.NA)
# Out:
# 4924    ThisPREDEPROVENCESHEABUTTERENRICHEDARTISANALFR...
# 4187    Lavenderismyfavoritesoapfragrancesoitisnosurpr...
# 4856    IlovePredeProvencesoapsbutwasintenselycuriousa...
# 4849    ThisPREDEPROVENCESandalwoodSHEABUTTERENRICHEDS...
# 4848    ThisPREDEPROVENCEPATCHOULISHEABUTTERENRICHEDSO...
#                               ...
# 3130    Sizecolourandprintallaboveaveragebutdoesnotwas...
# 816     GreatproductkidsloveitanditsmellsgoodtooEasily...
# 405      extremelypleasedverypleasantscentverylonglasting
# 643                                            Myfavorite
# 606                         VerygoodproductIuseiteveryday
# Name: reviewText, Length: 1874, dtype: str

# %%
sorted_df.head()
# Out:
#       overall  verified   reviewTime      reviewerID        asin  \
# 4924      5.0     False  08 26, 2017  A2MJ8OL2FYN7CW  B00W259T7G
# 4187      5.0     False   09 4, 2017  A2MJ8OL2FYN7CW  B001LNODUS
# 4856      5.0     False  09 21, 2017  A2MJ8OL2FYN7CW  B00W259T7G
# 4849      5.0     False  09 27, 2017  A2MJ8OL2FYN7CW  B00W259T7G
# 4848      5.0     False  09 27, 2017  A2MJ8OL2FYN7CW  B00W259T7G
#
#                                                 style reviewerName  \
# 4924   {'Size:': ' 250 Gram', 'Color:': ' Olive Oil'}     Lynne E.
# 4187                        {'Color:': ' Shower Gel'}     Lynne E.
# 4856    {'Size:': ' 150 Gram', 'Color:': ' Sea Salt'}     Lynne E.
# 4849  {'Size:': ' 250 Gram', 'Color:': ' Sandalwood'}     Lynne E.
# 4848   {'Size:': ' 250 Gram', 'Color:': ' Patchouli'}     Lynne E.
#
#                                              reviewText  \
# 4924  This PRE DE PROVENCE SHEA BUTTER ENRICHED ARTI...
# 4187  Lavender is my favorite soap fragrance, so it ...
# 4856  I love Pre de Provence soaps, but was intensel...
# 4849  This PRE DE PROVENCE Sandalwood SHEA BUTTER EN...
# 4848  This PRE DE PROVENCE PATCHOULI SHEA BUTTER ENR...
#
#                                                 summary  unixReviewTime vote  \
# 4924    Feels Luxurious, Doesn't Dry Out Sensitive Skin      1503705600  NaN
# 4187  Clear Gel Creates Nice Lather With Delicate La...      1504483200  NaN
# 4856  Luxurious French Soap Has Fresh Sea Breeze Fra...      1505952000    7
# 4849  Luxurious French Soap With Mild, Masculine Fra...      1506470400  NaN
# 4848  Luxurious French Soap With Musky Masculine Fra...      1506470400  NaN
#
#      image   unixTime  Score
# 4924   NaN 2017-08-26      1
# 4187   NaN 2017-09-04      1
# 4856   NaN 2017-09-21      1
# 4849   NaN 2017-09-27      1
# 4848   NaN 2017-09-27      1

# %%
sorted_df["reviewText"].values[1]
# Out:
# 'Lavender is my favorite soap fragrance, so it is no surprise that I love this PRE DE PROVENCE FRENCH LAVENDER BATH & SHOWER GEL.  For the shower, a pump or two is enough for a nice lather, and the lather washes off easily.\n\nThe lavender fragrance is delicate, and it lingers for only a short time.  It does not overwhelm perfume, aftershave lotion, shampoo, or other scented products you may like to use.  The clear gel arrives in an attractive square pump dispenser.\n\nThe shower gel leaves my skin silky smooth, and it does not irritate my sensitive skin.'

# %% [markdown]
# __Removing new line__

# %%
sorted_df["reviewText"]=sorted_df["reviewText"].apply(lambda x: re.sub(r'\n+',".",x) if pd.notna(x) else pd.NA)

# %%
sorted_df["reviewText"].values[1]
# Out:
# 'Lavender is my favorite soap fragrance, so it is no surprise that I love this PRE DE PROVENCE FRENCH LAVENDER BATH & SHOWER GEL.  For the shower, a pump or two is enough for a nice lather, and the lather washes off easily..The lavender fragrance is delicate, and it lingers for only a short time.  It does not overwhelm perfume, aftershave lotion, shampoo, or other scented products you may like to use.  The clear gel arrives in an attractive square pump dispenser..The shower gel leaves my skin silky smooth, and it does not irritate my sensitive skin.'

# %% [markdown]
# __Removing stop words__

# %%
stop_words  = set([
    'a','about','above','after','again','against','all','also','am','an','and',
    'any','are','as','at','be','because','been','before','being','below','between',
    'both','but','by',
    'can','could','did','do','does','doing','down','during',
    'each','few','for','from','further',
    'had','has','have','having','he','her','here','hers','herself','him','himself',
    'his','how',
    'i','if','in','into','is','it','its','itself',
    'just',
    'me','more','most','my','myself',
    'of','off','on','once','only','or','other','our','ours','ourselves','out','over',
    'same','she','should','so','some','such',
    'than','that','the','their','theirs','them','themselves','then','there',
    'these','they','this','those','through','to','too',
    'under','until','up',
    'very',
    'was','we','were','what','when','where','which','while','who','whom','why',
    'with',
    'you','your','yours','yourself','yourselves',
    'br','www','http'
])

# %%
for text in  sorted_df["reviewText"].values.tolist():
    print(text)
    break
# Out:
# This PRE DE PROVENCE SHEA BUTTER ENRICHED ARTISANAL FRENCH SOAP BAR (Olive Oil (250 g)) lathers beautifully, and feels luxurious.  It does not dry out or irritate my sensitive skin, so I can use it every day.  This is a large 250 gram olive oil bar that gives good value for the money (about $7 on Amazon).

# %%
for i,text in zip(sorted_df.index, sorted_df["reviewText"]):
    if pd.notna(text):
        texts = text.split(" ")
        print(texts)
        print("______________")
        for txt in texts:
            if txt.lower() in stop_words:
              texts.remove(txt)
        texts = " ".join(texts)
        sorted_df.loc[i,"Text_preprocessed"]=texts
        print(texts)
    else:
     sorted_df.loc[i,"Text_preprocessed"] = pd.NA
# Out:
# ['This', 'PRE', 'DE', 'PROVENCE', 'SHEA', 'BUTTER', 'ENRICHED', 'ARTISANAL', 'FRENCH', 'SOAP', 'BAR', '(Olive', 'Oil', '(250', 'g))', 'lathers', 'beautifully,', 'and', 'feels', 'luxurious.', '', 'It', 'does', 'not', 'dry', 'out', 'or', 'irritate', 'my', 'sensitive', 'skin,', 'so', 'I', 'can', 'use', 'it', 'every', 'day.', '', 'This', 'is', 'a', 'large', '250', 'gram', 'olive', 'oil', 'bar', 'that', 'gives', 'good', 'value', 'for', 'the', 'money', '(about', '$7', 'on', 'Amazon).']
# ______________
# PRE DE PROVENCE SHEA BUTTER ENRICHED ARTISANAL FRENCH SOAP BAR (Olive Oil (250 g)) lathers beautifully, feels luxurious.  does not dry or irritate sensitive skin, I use every day.  is large 250 gram olive oil bar gives good value the money (about $7 Amazon).
# ['Lavender', 'is', 'my', 'favorite', 'soap', 'fragrance,', 'so', 'it', 'is', 'no', 'surprise', 'that', 'I', 'love', 'this', 'PRE', 'DE', 'PROVENCE', 'FRENCH', 'LAVENDER', 'BATH', '&', 'SHOWER', 'GEL.', '', 'For', 'the', 'shower,', 'a', 'pump', 'or', 'two', 'is', 'enough', 'for', 'a', 'nice', 'lather,', 'and', 'the', 'lather', 'washes', 'off', 'easily..The', 'lavender', 'fragrance', 'is', 'delicate,', 'and', 'it', 'lingers', 'for', 'only', 'a', 'short', 'time.', '', 'It', 'does', 'not', 'overwhelm', 'perfume,', 'aftershave', 'lotion,', 'shampoo,', 'or', 'other', 'scented', 'products', 'you', 'may', 'like', 'to', 'use.', '', 'The', 'clear', 'gel', 'arrives', 'in', 'an', 'attractive', 'square', 'pump', 'dispenser..The', 'shower', 'gel', 'leaves', 'my', 'skin', 'silky', 'smooth,', 'and', 'it', 'does', 'not', 'irritate', 'my', 'sensitive', 'skin.']
# ______________
# Lavender favorite soap fragrance, it no surprise I love PRE DE PROVENCE FRENCH LAVENDER BATH & SHOWER GEL.  the shower, pump two enough nice lather, the lather washes easily..The lavender fragrance delicate, it lingers only a short time.  not overwhelm perfume, aftershave lotion, shampoo, other scented products may like use.  clear gel arrives an attractive square pump dispenser..The shower gel leaves skin silky smooth, it does not irritate my sensitive skin.
# ['I', 'love', 'Pre', 'de', 'Provence', 'soaps,', 'but', 'was', 'intensely', 'curious', 'about', 'the', 'Sea', 'Salt', 'bar.', '', 'What', 'would', 'it', 'smell', 'like?', '', 'Why', 'would', 'I', 'want', 'to', 'wash', 'my', 'hands', 'with', 'sea', 'salt?', '', 'Happily,', 'this', 'PRE', 'DE', 'PROVENCE', 'SEA', 'SALT', 'FRENCH', 'SOAP', 'BAR', '(150g,', '5.2', 'Ounce)', 'is', 'no', 'different', 'from', 'the', 'other', 'Pre', 'de', 'Provence', 'soaps--it', 'smells', 'wonderful,', 'and', 'produces', 'a', 'rich,', 'thick', 'lather..The', 'fragrance', 'is', 'hard', 'to', 'describe.', '', 'Its', 'kind', 'of', 'floral,', 'but', 'maybe', 'is', 'best', 'described', 'as', 'fresh', 'sea', 'breeze.', '', 'It', 'makes', 'one', 'think', 'of', 'fresh', 'air', 'and', 'sunshine.', '', 'The', 'fragrance', 'does', 'not', 'linger', 'overlong.', '', 'The', 'soap', 'does', 'not', 'irritate', 'my', 'sensitive', 'skin,', 'but', 'may', 'be', 'a', 'little', 'more', 'drying', 'than', 'other', 'Pre', 'de', 'Provence', 'soaps', '(unless', 'it', 'is', 'my', 'imagination', 'working', 'overtime)..The', 'soap', 'definitely', 'contains', 'salt.', 'The', 'ingredients', 'are:', '', 'sodium', 'palmate,', 'sodium', 'palm', 'kernelate,', 'water,', 'fragrance,', 'palm', 'acid,', 'titanium', 'dioxide,', 'glycerin,', 'palm', 'kernel', 'acid,', 'SODIUM', 'CHLORIDE,', 'shea', 'butter,', 'sodium', 'hydroxide,', 'tetrasodium', 'edta,', 'tetrasodium', 'etidronate,', 'benzyl', 'salicylate,', 'linalool,', 'geraniol,', 'citral.']
# ______________
# love Pre de Provence soaps, was intensely curious the Sea Salt bar.  would smell like?  would want wash hands sea salt?  Happily, PRE DE PROVENCE SEA SALT FRENCH SOAP BAR (150g, 5.2 Ounce) no different the Pre de Provence soaps--it smells wonderful, produces rich, thick lather..The fragrance hard describe.  kind floral, maybe best described fresh sea breeze.  makes one think fresh air sunshine.  fragrance not linger overlong.  soap not irritate sensitive skin, may a little drying other Pre de Provence soaps (unless is imagination working overtime)..The soap definitely contains salt. ingredients are:  sodium palmate, sodium palm kernelate, water, fragrance, palm acid, titanium dioxide, glycerin, palm kernel acid, SODIUM CHLORIDE, shea butter, sodium hydroxide, tetrasodium edta, tetrasodium etidronate, benzyl salicylate, linalool, geraniol, citral.
# ['This', 'PRE', 'DE', 'PROVENCE', 'Sandalwood', 'SHEA', 'BUTTER', 'ENRICHED', 'SOAP', '(250', 'Gram)', 'should', 'appeal', 'to', 'the', 'male', 'members', 'of', 'the', 'household,', 'because', 'of', 'the', 'mild,', 'woody', 'fragrance.', '', '(Most', 'Pre', 'de', 'Provence', 'soaps', 'have', 'fairly', 'strong,', 'flowery', 'fragrances.).It', 'is', 'a', 'large', 'bar', 'of', 'luxurious', 'French', 'soap.', '', 'It', 'lathers', 'beautifully,', 'and', 'the', 'fragrance', 'never', 'lingers', 'too', 'long.', '', 'The', 'soap', 'is', 'very', 'gentle,', 'and', 'does', 'not', 'irritate', 'sensitive', 'skin.']
# ______________
# PRE DE PROVENCE Sandalwood SHEA BUTTER ENRICHED SOAP (250 Gram) appeal male members the household, the mild, woody fragrance.  (Most Pre de Provence soaps fairly strong, flowery fragrances.).It a large bar of luxurious French soap.  lathers beautifully, the fragrance never lingers long.  soap very gentle, does not irritate sensitive skin.
# ['This', 'PRE', 'DE', 'PROVENCE', 'PATCHOULI', 'SHEA', 'BUTTER', 'ENRICHED', 'SOAP', '(250', 'Gram)', 'has', 'the', 'mild,', 'musky', 'fragrance', 'that', 'many', 'women', 'find', 'sexy,', 'but', 'the', 'fragrance', 'is', 'risky.', '', 'To', 'some', 'people', '(including', 'me)', 'it', 'smells', 'like', 'fungus', 'or', 'damp', 'basement.', '', 'Still,', 'this', 'soap', 'may', 'appeal', 'to', 'male', 'household', 'members,', 'because', 'it', 'is', 'so', 'different', 'from', 'most', 'other', 'Pre', 'de', 'Provence', 'soaps', '(with', 'their', 'fairly', 'strong,', 'flowery', 'fragrances)..This', 'is', 'a', 'large', 'bar', 'of', 'luxurious', 'French', 'soap.', '', 'It', 'lathers', 'beautifully,', 'and', 'the', 'fragrance', 'never', 'lingers', 'too', 'long.', '', 'The', 'soap', 'is', 'very', 'gentle,', 'and', 'does', 'not', 'irritate', 'sensitive', 'skin..For', 'men,', 'a', 'much', 'safer', 'Pre', 'de', 'Provence', 'soap', 'is', 'the', 'Sandalwood', 'bar', '(see\xa0Pre', 'de', 'Provence', 'Sandalwood).']
# ______________
# PRE DE PROVENCE PATCHOULI SHEA BUTTER ENRICHED SOAP (250 Gram) the mild, musky fragrance many women find sexy, the fragrance risky.  some people (including me) smells like fungus damp basement.  Still, soap may appeal male household members, it so different most Pre de Provence soaps (with fairly strong, flowery fragrances)..This large bar luxurious French soap.  lathers beautifully, the fragrance never lingers long.  soap very gentle, does not irritate sensitive skin..For men, a much safer Pre de Provence soap the Sandalwood bar (see Pre de Provence Sandalwood).
# ['My', 'kids', 'love', 'using', 'the', 'Colgate', 'pumps.', 'I', 'think', 'it', 'just', 'seems', 'fun', 'to', 'them', 'and', 'they', 'are', 'easier', 'for', 'kids', 'to', 'operate', 'than', 'having', 'to', 'squeeze', 'tubes.', 'I', 'do', 'feel', 'like', 'the', 'pumps', 'leave', 'a', 'little', 'bit', 'left', 'in', 'the', 'bottom', 'though', 'so', 'you', 'get', 'a', 'little', 'bit', 'less', 'product', 'with', 'them.', 'The', 'pumps', 'are', 'definitely', 'less', 'messy', 'though..Our', 'order', 'came', 'as', '6', 'pumps', 'of', 'Colgate', 'Maximum', 'Cavity', 'Protection', 'in', 'mild', 'bubble', 'fruit', 'flavor.', 'The', 'toothpaste', 'is', 'a', 'blue', 'gel.', 'Its', 'slightly', 'fruity', 'but', 'still', 'minty.', 'All', '6', 'pumps', 'had', 'an', 'expiration', 'date', 'of', '10/2017', '(this', 'is', '8/2016)', 'so', 'the', 'expiration', 'date', 'is', 'over', 'a', 'year', 'out', '-', 'plenty', 'of', 'time', 'to', 'use', 'all', '6', 'pumps.', 'All', 'the', 'pumps', 'have', 'a', 'safety', 'seal', 'on', 'the', 'pump', 'that', 'has', 'to', 'be', 'broken', 'off', 'so', 'you', 'know', 'they', 'are', 'sealed', 'and', 'safe..The', 'kids', 'really', 'like', 'this', 'flavor', 'and', 'the', 'pump.']
# ______________
# kids love using Colgate pumps. think just seems fun them easier kids operate having squeeze tubes. do feel like pumps leave little bit left the bottom though get little bit less product them. pumps definitely less messy though..Our order came 6 pumps Colgate Maximum Cavity Protection mild bubble fruit flavor. toothpaste blue gel. slightly fruity still minty. 6 pumps an expiration date 10/2017 (this 8/2016) the expiration date over a year - plenty time use 6 pumps. the pumps a safety seal the pump has be broken so you know they are sealed safe..The kids really like flavor the pump.
# ['Review', 'for', 'Starflower:.This', 'is', 'a', 'nice', 'bar', 'of', 'soap.', 'It', 'has', 'a', 'hard', 'consistency,', 'not', 'a', 'soft', 'bar', 'so', 'it', 'seems', 'to', 'last', 'longer.', 'The', 'soap', 'provides', 'a', 'lot', 'of', 'suds', 'which', 'makes', 'you', 'feel', 'like', 'you', 'are', 'getting', 'clean.', 'It', 'is', 'a', 'large', 'size', 'too', 'which', 'my', 'husband', 'really', 'loves..I', 'had', 'never', 'smelled', 'starflower', 'before.', 'The', 'scent', 'of', 'the', 'soap', 'is', 'a', 'floral', 'but', 'not', 'in', 'a', 'heavy', 'or', 'sweet', 'type', 'scent,', 'it', 'smells', 'nothing', 'like', 'roses', 'or', 'magnolias', 'but', 'is', 'just', 'clean', 'floral', 'scent.', 'Im', 'not', 'a', 'big', 'fan', 'of', 'florals', 'and', 'this', 'one', 'is', 'ok,', 'my', 'husband', 'doesnt', 'care', 'for', 'anything', 'girly', 'scented', 'and', 'he', 'doesnt', 'mind', 'this', 'one', 'either.']
# ______________
# Review Starflower:.This nice bar soap. has hard consistency, not soft bar seems last longer. soap provides lot suds makes feel like are getting clean. large size which husband really loves..I never smelled starflower before. scent the soap a floral not a heavy sweet type scent, it smells nothing like roses magnolias is clean floral scent. Im not a big fan florals one is ok, husband doesnt care anything girly scented he doesnt mind this one either.
# ['Review', 'for', 'Loofah:.I', 'have', 'tried', 'loofahs', 'in', 'the', 'past', 'and', 'was', 'never', 'a', 'big', 'fan', 'but', 'I', 'gave', 'the', 'Urban', 'Spa', 'Loofah', 'a', 'try', 'and', 'Im', 'glad', 'that', 'I', 'did.', 'The', 'loofah', 'arrives', 'a', 'little', 'flat', 'from', 'packaging', 'but', 'swells', 'up', 'nice', 'and', 'round', 'in', 'the', 'water.', 'It', 'is', 'surprisingly', 'soft', 'in', 'the', 'water.', 'It', 'works', 'great', 'with', 'body', 'wash', 'providing', 'lots', 'of', 'suds..I', 'like', 'that', 'it', 'has', 'an', 'attached', 'ribbon', 'and', 'suction', 'cup.', 'I', 'thought', 'that', 'the', 'suction', 'cup', 'being', 'attached', 'would', 'bother', 'me', 'as', 'I', 'used', 'it', 'but', 'it', 'has', 'not.', 'Its', 'nice', 'that', 'I', 'can', 'hang', 'it', 'on', 'my', 'shower', 'door.', 'It', 'attaches', 'securely', 'and', 'I', 'have', 'not', 'had', 'any', 'trouble', 'with', 'it', 'slipping', 'or', 'sliding', 'on', 'the', 'glass.']
# ______________
# Review Loofah:.I tried loofahs past was never big fan gave the Urban Spa Loofah try Im glad did. loofah arrives little flat packaging swells nice round the water. is surprisingly soft the water. works great body wash providing lots suds..I like an attached ribbon suction cup. I thought the suction cup attached would bother as I used but has not. nice I hang it shower door. attaches securely I not any trouble it slipping sliding on the glass.
# ['Have', 'used', 'for', 'a', 'long', 'time', 'and', 'nothing', 'has', 'worked', 'better.', 'This', 'is', 'a', 'winner', 'and', 'I', 'will', 'continue', 'to', 'purchase', 'it.']
# ______________
# used long time nothing worked better. is a winner I will continue purchase it.
# ['This', 'is', 'my', 'favorite', 'floss.', '', 'I', 'do', 'feel', 'like', 'my', 'teeth', 'are', 'much', 'cleaner', 'when', 'I', 'use', 'it.', '', 'Like', 'the', 'name', 'says,', 'it', 'glides', 'easily', 'between', 'my', 'teeth,', 'no', 'sticking', 'or', 'shredding.', '', 'The', 'plastic', 'container', 'is', 'small,', 'compact', 'and', 'attractive.', '', 'The', 'minty', 'flavor', 'is', 'a', 'nice', 'touch.']
# ______________
# favorite floss.  do feel like teeth much cleaner I use it.  Like name says, glides easily my teeth, no sticking shredding.  plastic container small, compact attractive.  minty flavor is a nice touch.
# ['This', 'floss', 'does', 'feel', 'softer', 'in', 'the', 'hands.', 'It', 'is', 'just', 'as', 'strong,', 'does', 'not', 'shred', 'and', 'glides', 'between', 'teeth', 'just', 'as', 'smoothly', 'as', 'original', 'Glide..I', 'could', 'do', 'without', 'the', 'mint', 'flavor.', 'I', 'do', 'not', 'taste', 'the', 'flavor', 'at', 'all,', 'but', 'it', 'makes', 'the', 'floss', 'smell', 'medicinal,', 'not', 'so', 'pleasant.', 'Usually,', 'mint', 'floss', 'is', 'refreshing,', 'but', 'not', 'here.', 'I', 'would', 'like', 'this', 'floss', 'without', 'flavor', 'and', 'will', 'try', 'Glide', 'Comfort', 'Plus', 'Unflavored', 'next', 'time.']
# ______________
# floss feel softer hands. strong, not shred glides teeth as smoothly as original Glide..I do without mint flavor. do not taste flavor all, it makes the floss smell medicinal, not pleasant. Usually, mint floss is refreshing, not here. would like floss without flavor will try Glide Comfort Plus Unflavored next time.
# ['My', 'daughter,', 'a', 'verified', 'kid,', 'will', 'not', 'use', 'adult', 'toothpaste.', '', 'She', 'almost', 'refused', 'to', 'use', 'Colgate', 'Kids', 'toothpaste', 'because', 'it', 'looks', 'so', 'much', 'like', 'adult', 'toothpaste.', '', 'Hint', 'to', 'the', 'makers:', 'Your', 'design', 'team', 'really', 'needs', 'to', 'step', 'up', 'to', 'the', 'plate.', '', 'Throw', 'some', 'color', 'on', 'that', 'tube!.After', 'I', 'convinced', 'her', 'to', 'use', 'the', 'toothpaste,', 'she', 'was', 'quite', 'happy.', '', 'Bubblegum', '(ahem,', 'bubble', 'fruit)', 'is', 'not', 'her', 'favorite', 'flavor,', 'but', 'she', 'says', 'it', 'tastes', 'just', 'like', 'the', 'other', 'sparkly', 'toothpastes,', 'and', 'she', 'likes', 'the', 'pump', 'action', 'because', 'it', 'is', 'less', 'mess', 'than', 'traditional', 'tubes.', '', 'Yes,', 'the', 'pump', 'and', 'the', 'rocket', 'stand', 'are', 'definite', 'pluses.', '', 'No', 'more', 'toothpaste', 'all', 'over', 'the', 'sink.', '', 'She', 'still', 'uses', 'the', 'toothpaste', 'without', 'complaint,', 'so', 'it', 'is', 'a', 'thumbs', 'up', 'from', 'her.']
# ______________
# daughter, verified kid, will not use adult toothpaste.  almost refused use Colgate Kids toothpaste looks much like adult toothpaste.  Hint makers: design team really needs step to plate.  Throw color that tube!.After convinced to use toothpaste, was quite happy.  Bubblegum (ahem, bubble fruit) not favorite flavor, she says it tastes like other sparkly toothpastes, she likes pump action it less mess traditional tubes.  Yes, pump rocket stand definite pluses.  No toothpaste over the sink.  still uses the toothpaste without complaint, it a thumbs from her.
# ['Clean', '&', 'Clear', 'sure', 'knows', 'how', 'to', 'make', 'a', 'cleanser', 'feel', 'gentle.', '', 'It', 'is', 'not', 'sudsy', 'like', 'a', 'soap.', '', 'It', 'is', 'more', 'like', 'a', 'lotion.', '', 'The', 'scent', 'was', 'hard', 'to', 'pinpoint,', 'but', 'I', 'would', 'say', 'it', 'is', 'a', 'bit', 'like', 'cucumber.', '', 'This', 'has', 'salicylic', 'acid,', 'folks,', 'the', 'stuff', 'that', 'is', 'in', 'acne', 'treatment.', '', 'I', 'should', 'have', 'known,', 'I', 'mean', '"Clean', '&', 'Clear,"', 'right?', 'My', 'face', 'feels', 'clean', 'afterwards.', 'The', 'one', 'star', 'deduction', 'is', 'for', 'the', 'scent,', 'which', 'I', 'do', 'not', 'think', 'is', 'the', 'greatest.']
# ______________
# Clean & Clear sure knows make cleanser feel gentle.  not sudsy like soap.  like lotion.  scent hard to pinpoint, would say is bit like cucumber.  has salicylic acid, folks, stuff is acne treatment.  should known, I mean "Clean & Clear," right? face feels clean afterwards. one star deduction is for scent, I not think is the greatest.
# ['This', 'soap', 'goes', 'on', 'as', 'smooth', 'as', 'butter.', '', 'Even', 'with', 'the', 'bits', 'of', 'stuff', 'I', 'am', 'sure', 'is', 'there', 'for', 'exfoliation,', 'I', 'only', 'sense', 'richness.', '', 'The', 'floral', 'scent', 'is', 'light,', 'not', 'overpowering,', 'and', 'I', 'do', 'not', 'notice', 'myself', 'wearing', 'it', 'after', 'my', 'shower', 'is', 'done.', '', 'The', 'bar', 'is', 'much', 'fatter', 'than', 'standard', 'bars', 'from', 'the', 'grocery', 'store.', 'Even', 'though', 'it', 'feels', 'like', 'it', 'melts', 'in', 'my', 'hands,', 'it', 'actually', 'lasts', 'and', 'lasts.', '', 'With', 'this', 'soap,', 'I', 'shower', 'in', 'the', 'lap', 'of', 'luxury.']
# ______________
# soap goes smooth as butter.  Even the bits stuff am sure there exfoliation, only sense richness.  floral scent light, not overpowering, not notice wearing after shower done.  bar much fatter standard bars the grocery store. Even though feels like melts my hands, actually lasts lasts.  this soap, I shower the lap luxury.
# ['I', 'have', 'not', 'used', 'this', 'mitt', 'to', 'hold', 'my', 'small', 'soaps,', 'but', 'I', 'have', 'used', 'it', 'with', 'body', 'wash.', '', 'The', 'jute', 'side', 'does', 'not', 'feel', 'so', 'rough', 'when', 'it', 'is', 'dry,', 'but', 'do', 'not', 'let', 'that', 'fool', 'you.', '', 'It', 'can', 'really', 'scrub!', '', 'And', 'boy,', 'are', 'there', 'areas', 'of', 'my', 'body', 'that', 'need', 'it.', '', 'The', 'other', 'side', 'is', 'bamboo', 'fiber,', 'which', 'is', 'super', 'soft.', '', 'It', 'holds', 'all', 'my', 'body', 'wash,', 'maybe', 'too', 'well', 'because', 'I', 'am', 'not', 'getting', 'quite', 'the', 'number', 'of', 'suds', 'that', 'I', 'expect.', '', 'However,', 'I', 'do', 'like', 'this', 'mitt', 'because', 'it', 'scrubs', 'me', 'cleaner', 'than', 'I', 'have', 'felt', 'for', 'a', 'long', 'time.', '', 'Dead', 'skin', 'cells', 'be', 'gone!']
# ______________
# not used mitt hold small soaps, used with body wash.  jute side not feel rough it dry, do not let fool you.  can really scrub!  boy, there areas my body need it.  other side bamboo fiber, is super soft.  holds my body wash, maybe well I not getting quite number suds I expect.  However, I do like mitt it scrubs cleaner I have felt a long time.  Dead skin cells gone!
# ['I', 'know', 'sandalwood', 'is', 'a', 'more', 'manly', 'scent;', 'but', 'even', 'though', 'I', 'am', 'not', 'sure', 'wood', 'is', 'what', 'I', 'want', 'my', 'man', 'to', 'wear,', 'it', 'is', 'the', 'best-smelling', 'wood', 'I', 'I', 'have', 'ever', 'smelled', 'in', 'a', 'soap.', '', 'Women', 'can', 'wear', 'it,', 'too,', 'by', 'the', 'way.', '', 'Although', 'I', 'have', 'to', 'say,', 'this', 'bar', 'is', 'big,', 'so', 'make', 'sure', 'you', 'have', 'hands', 'big', 'enough', 'to', 'wrap', 'around', 'it.']
# ______________
# know sandalwood a manly scent; even though am not sure wood what want man wear, best-smelling wood ever smelled a soap.  Women wear it, too, the way.  Although I have say, bar is big, make sure have hands big enough wrap around it.
# ['ive', 'been', 'using', 'this', 'cleanser', 'for', 'a', 'few', 'years', 'now.', 'i', 'only', 'found', 'it', 'in', 'korea', 'and', 'brought', 'a', 'few', 'tubes', 'every', 'time', 'i', 'visit', '(once', 'a', 'year).', 'gentle', 'but', 'gets', 'all', 'the', 'crap', 'off.', 'so', 'happy', 'to', 'see', 'it', 'available', 'stateside', 'now.']
# ______________
# ive using cleanser years now. only found in korea brought few tubes every time visit (once a year). gentle gets the crap off. happy see available stateside now.
# ['Always', 'excellent,', 'third', 'time', 'ordering,', 'more', 'to', 'come,', 'husband', 'loves', 'the', 'soap.']
# ______________
# Always excellent, third time ordering, to come, husband loves soap.
# ['This', 'is', '.', '.', '.', 'a', 'bath', 'brush!', '', 'With', 'nice', 'thick', 'bristles', 'on', 'one', 'side,', 'and', 'rounded', 'plastic', 'knobs', 'on', 'the', 'other', 'side.', 'Both', 'are', 'suitable', 'for', 'cleaning', 'your', 'back', 'and', 'any', 'other', 'area', 'that', 'is', 'hard', 'to', 'reach,', 'though', 'I', 'prefer', 'the', 'bristle', 'side.', 'As', 'for', 'reducing', 'cellulite', '.', '.', '.', 'not', 'really.']
# ______________
# is . . . bath brush!  nice thick bristles one side, rounded plastic knobs side. are suitable cleaning back any area is hard reach, though prefer the bristle side. for reducing cellulite . . . not really.
# ['This', 'is', 'a', 'medium-sized', 'bar', 'of', 'hard', 'soap', 'with', 'a', 'pleasant', 'lemon', 'scent.', 'I', 'have', 'sensitive', 'skin,', 'and', 'this', 'soap', 'does', 'not', 'irritate', 'it.', 'Perfect', 'for', 'the', 'tub,', 'sink,', 'or', 'a', 'luxury', 'gift.']
# ______________
# is medium-sized bar hard soap a pleasant lemon scent. have sensitive skin, this soap not irritate it. Perfect the tub, sink, a luxury gift.
# ['These', 'bath', 'salts', 'do', 'smell', 'like', 'real', 'lavender,', 'and', 'turn', 'bathing', 'into', 'a', 'luxurious', 'experience.', '', 'They', 'would', 'make', 'a', 'nice', 'but', 'inexpensive', 'holiday', 'gift.']
# ______________
# bath salts smell like real lavender, turn bathing luxurious experience.  would make a nice inexpensive holiday gift.
# ['worked', 'great!!']
# ______________
# worked great!!
# ['worked', 'great']
# ______________
# worked great
# ['Worked', 'great!!']
# ______________
# Worked great!!
# ['Worked', 'great!!', 'I', 'just', 'wonder', 'how', 'long', 'they', 'last.', 'Guess', 'I', 'will', 'find', 'out.', 'This', 'product', 'is', 'very', 'easy', 'to', 'install!!']
# ______________
# Worked great!! just wonder long last. Guess will find out. product very easy install!!
# ['Great!!']
# ______________
# Great!!
# ['I', 'love', 'these', 'shoes', 'and', 'have', 'worn', 'them', 'for', 'a', 'long', 'time.', 'That', 'are', 'comfy,', 'thinner', 'on', 'the', 'top', '&', 'sole', 'and', 'are', 'very', 'cute!']
# ______________
# love shoes have worn for long time. are comfy, thinner the top & sole are cute!
# ['Comfortable', 'athletic', 'shoe,', '', 'good', 'for', 'the', 'gym', '(ellipical,', 'tredmill,', 'etc.)', 'Fit', 'is', 'good,', 'and', 'shoe', 'is', 'really', 'lightweight', 'and', 'comfy.']
# ______________
# Comfortable athletic shoe,  good the gym (ellipical, tredmill, etc.) Fit good, shoe really lightweight comfy.
# ['Excellent']
# ______________
# Excellent
# ['HALE', 'BERRY', 'Pure', 'Orchid', 'is', 'a', 'wonderful', 'fragrance,', 'it', 'is', 'becoming', 'harder', 'to', 'find', 'in', 'dept.', 'stores.']
# ______________
# HALE BERRY Pure Orchid a wonderful fragrance, is becoming harder find dept. stores.
# ['Love', 'them!', '', 'Very', 'comfortable', 'and', 'great', 'for', 'weight', 'training!']
# ______________
# Love them!  comfortable great weight training!
# ['I', 'am', 'a', 'diehard', 'bare', 'minerals', 'fan.', 'Every', 'single', 'brush', 'I', 'own', 'is', 'by', 'bare', 'minerals', 'EXCEPT', 'for', 'this', 'one.', 'I', 'have', 'used', 'this', 'brush', 'nearly', 'every', 'day', 'for', 'at', 'least', '5', 'years', 'now', 'and', 'the', 'only', 'reason', 'I', 'can', 'tell', 'its', 'not', 'brand-new', 'is', 'because', 'the', 'words', '"Elizabeth', 'Arden"', 'have', 'worn', 'off.', 'I', 'have', 'never', 'ever', 'had', 'a', 'single', 'bristle', 'fall', 'out', 'of', 'the', 'brush,', 'even', 'when', 'I', 'am', 'washing', 'it.', 'I', 'also', 'take', 'good', 'care', 'of', 'it', 'and', 'wash', 'it', 'every', 'week', 'with', 'baby', 'shampoo.', '(Side', 'Note:', 'baby', 'shampoo', 'is', 'significantly', 'less', 'expensive', 'and', 'works', 'better', 'than', 'any', '"makeup', 'brush', 'shampoo").The', 'bristles', 'are', 'unbelievably', 'soft', 'and', 'give', 'a', 'really', 'even', 'powder', 'coverage', 'and', 'its', 'very', 'easy', 'to', 'vary', 'the', 'fullness', 'of', 'coverage', 'with', 'this', 'brush.', 'The', 'angle', 'is', 'absolutely', 'perfect', 'for', 'applying', 'foundation.', 'I', 'find', 'that', 'this', 'brush', 'works', 'really', 'well', 'with', 'the', 'Bare', 'Minerals', 'loose', 'powder', 'foundation,', 'though', 'I', 'have', 'gotten', 'wonderful', 'results', 'using', 'this', 'brush', 'with', 'pressed', 'powder', 'as', 'well..This', 'brush', 'is', 'extremely', 'high', 'quality,', 'worth', 'every', 'penny', 'and', 'if', 'you', 'take', 'care', 'of', 'it,', 'it', 'will', 'last', 'you', 'forever.']
# ______________
# diehard bare minerals fan. Every single brush own by bare minerals EXCEPT one. used brush nearly every day at least 5 years now reason can tell not brand-new because words "Elizabeth Arden" have worn off. have never ever single bristle fall brush, even am washing it. also take good care wash every week baby shampoo. (Side Note: baby shampoo significantly less expensive works better any "makeup brush shampoo").The bristles unbelievably soft give a really even powder coverage its easy vary the fullness coverage this brush. angle absolutely perfect applying foundation. find this brush works really well the Bare Minerals loose powder foundation, though I have gotten wonderful results using this brush pressed powder well..This brush extremely high quality, worth every penny if take care of it, it will last forever.
# ['My', 'male', 'roommate', 'and', 'I', 'both', 'love', 'this', 'shampoo!', 'My', 'hair', 'looks', 'healthy', 'and', 'never', 'dry', 'or', 'frizzy', 'when', 'I', 'use', 'it', 'consistently.', 'All', 'the', 'Theorie', 'products', 'I', 'have', 'used', 'have', 'been', 'excellent', 'and', 'do', 'exactly', 'what', 'they', 'promise.', 'I', 'would', 'recommend', 'it', 'to', 'anyone!']
# ______________
# male roommate love shampoo! hair looks healthy never dry frizzy use consistently. the Theorie products I used have been excellent do exactly they promise. I would recommend to anyone!
# ['I', 'love', 'this', 'body', 'wash', 'though', 'it', 'is', 'becoming', 'harder', 'and', 'harder', 'to', 'find.', 'One', 'bottle', 'lasts', 'about', '6', 'months', 'for', 'me,', 'and', 'the', 'lather', 'is', 'amazing.', 'More', 'lather', 'than', 'any', 'other', 'shower', 'gel', 'I', 'have', 'ever', 'used.', 'The', 'smell', 'is', 'amazing;', 'not', 'too', 'strong,', 'not', 'too', 'faint.', 'It', 'is', 'too', 'bad', 'you', 'can', 'not', 'find', 'it', 'anymore.']
# ______________
# love body wash though becoming harder harder find. One bottle lasts 6 months me, the lather amazing. lather any shower gel have ever used. smell is amazing; not strong, not faint. is bad can not find anymore.
# ['Electric', 'razors', 'do', 'not', 'get', 'a', 'closer', 'shave', 'than', 'standards', 'ones', 'so', 'I', 'got', 'this.', '', 'This', 'did', 'not', 'do', 'the', 'trick', 'just', 'smells', 'bad.']
# ______________
# Electric razors not get closer shave standards ones I got this.  did not the trick smells bad.
# ['I', 'bought', 'this', 'to', 'smell', 'nice', 'after', 'I', 'shave.', '', 'When', 'I', 'put', 'it', 'on', 'I', 'smelled', 'awful.', '', 'I', 'am', '19', 'and', 'I', 'smelled', 'like', 'a', 'grandmother', 'with', 'too', 'much', 'perfume.']
# ______________
# bought to smell nice shave.  put on I smelled awful.  I am 19 I smelled like grandmother too much perfume.
# ['I', 'purchasaed', 'a', 'new', 'dryer', 'and', 'did', 'not', 'want', 'to', 'reuse', 'the', 'cord', 'from', 'my', 'old', 'unit.', 'This', 'unit', 'installed', 'in', 'a', 'pretty', 'straight', 'forward', 'manor.', 'Quality', 'was', 'as', 'expected.', 'No', 'Complaints']
# ______________
# purchasaed new dryer did not want reuse cord my old unit. unit installed a pretty straight forward manor. Quality as expected. No Complaints
# ['Worked', 'as', 'expected,', 'quality', 'GE', 'product.', 'Water', 'tastes', 'good.', 'Would', 'recommend', 'and', 'will', 'buy', 'again.']
# ______________
# Worked expected, quality GE product. Water tastes good. Would recommend will buy again.
# ['Moved', 'into', 'new', 'apt,', 'needed', 'dryer', 'vent', 'hose,', 'this', 'fit', 'the', 'bill.', 'The', 'compression', 'clamps', 'made', 'install', 'a', 'snap.']
# ______________
# Moved new apt, needed dryer vent hose, fit bill. compression clamps made install snap.
# ['This', 'soap', 'has', 'a', 'very', 'pleasant', 'smell,', 'but', 'most', 'importantly', 'it', 'is', 'very', 'concentrated', 'and', 'so', 'you', 'do', 'not', 'need', 'to', 'use', 'as', 'much', 'soap', '(saving', 'you', 'money', 'and', 'resources).', '', 'I', 'used', 'this', 'for', 'medical', 'reasons', '(jock', 'itch)', 'and', 'found', 'that', 'the', 'tea', 'tree', 'solution', 'helps.', '', 'However', 'Tea', 'Tree', 'is', 'often', 'very', 'costly', 'and', 'to', 'be', 'able', 'to', 'buy', 'this', 'in', 'bulk', 'at', 'such', 'a', 'good', 'value...', 'I', 'would', 'strongly', 'recommend.']
# ______________
# soap pleasant smell, most importantly concentrated so do not need use much soap (saving money resources).  used for medical reasons (jock itch) found the tea tree solution helps.  However Tea Tree is often costly able to buy in bulk such a good value... would strongly recommend.
# ['Excellent', 'product.']
# ______________
# Excellent product.
# ['Suffered', 'from', 'itchiness', 'under', 'my', 'hair', 'for', 'couple', 'of', 'years.', 'This', 'product', 'cured', 'the', 'itchiness', 'completely.', 'I', 'took', 'some', '4-5', 'drops', 'of', 'it', 'and', 'then', 'massaged', 'my', 'wet', 'head', 'for', 'a', 'minute', 'approximately.', 'After', '2', 'uses', 'noticed', 'a', 'considerable', 'difference.', 'It', 'definitely', 'gets', 'the', 'job', 'done!']
# ______________
# Suffered itchiness hair couple years. product cured itchiness completely. took 4-5 drops it then massaged my wet head minute approximately. 2 uses noticed a considerable difference. definitely gets job done!
# ['Miami', 'is', 'my', 'favorite']
# ______________
# Miami my favorite
# ['Very', 'good', 'stuff']
# ______________
# good stuff
# ['Been', 'looking', 'for', 'good', 'shampoo', 'that', 'would', 'work', 'with', 'my', 'dry', 'hair', 'for', 'a', 'long', 'time.', 'Tried', 'a', 'lot', 'of', 'options.', 'This', 'is', 'the', 'one.', 'Hair', 'feels', 'as', 'clean', 'as', 'possible', 'after', 'use.', 'Also,', 'deals', 'with', 'dandruff', 'problem', 'easily.', 'No', 'more', 'snowy', 'shoulders.']
# ______________
# looking good shampoo would work my dry hair long time. Tried a lot options. is one. Hair feels clean possible use. Also, deals dandruff problem easily. No snowy shoulders.
# ['This', 'product', 'was', 'definitely', 'a', 'good', 'deal', 'for', 'me.', 'No', 'surprises', 'about', 'the', 'delivery', 'estimated', 'time', 'and', 'especially', '(and', 'much', 'more', 'important)', 'because', 'the', 'product', 'that', 'arrived', 'here', 'was', 'exactly', 'what', 'I', 'was', 'expecting..The', 'seller', 'did', 'everything', 'just', 'like', 'promised', 'and', 'I', 'will', 'have', 'no', 'hesitation', 'in', 'buying', 'something', 'with', 'him', 'again', 'if', 'I', 'get', 'interested', 'by', 'any', 'of', 'his', 'products..By', 'the', 'way,', 'this', 'bottle', 'has', 'an', 'excelent', 'size', 'for', 'saving', 'money', 'by', 'buying', 'in', 'big', 'quantities,', 'so', 'a', 'definitely', 'recomend', 'it!']
# ______________
# product definitely good deal me. No surprises delivery estimated time especially (and much important) the product arrived exactly was expecting..The seller everything like promised I will no hesitation buying something him if I get interested any his products..By the way, bottle an excelent size saving money buying big quantities, a definitely recomend it!
# ['Excellent', 'product']
# ______________
# Excellent product
# ['This', 'is', 'the', 'best', 'body', 'wash', 'I', 'have', 'ever', 'used.', 'I', 'use', 'it', 'every', 'day', 'and', 'it', 'is', 'the', 'only', 'body', 'wash', 'that', 'leaves', 'my', 'body', 'smelling', 'good', 'for', 'a', 'prolonged', 'period', 'of', 'time,', 'and', 'at', 'the', 'same', 'time', 'reduce', 'the', 'greasiness', 'of', 'the', 'skin.']
# ______________
# best body wash have ever used. use every day it is body wash leaves body smelling good a prolonged period time, at same time reduce the greasiness the skin.
# ['Love', 'these', 'shoes!!', 'They', 'are', 'true', 'to', 'size', 'and', 'very', 'comfortable!!', 'This', 'is', 'my', 'second', 'pair', '-', 'I', 'wore', 'out', 'the', 'first', 'pair!!', 'Good', 'arch', 'support', '-', 'I', 'have', 'a', 'high', 'arch!!']
# ______________
# Love shoes!! are true size very comfortable!! is second pair - wore the first pair!! Good arch support - have high arch!!
# ['I', 'love', 'them!', 'They', 'fit', 'perfect', 'and', 'are', 'very', 'comfortable!!']
# ______________
# love them! fit perfect are comfortable!!
# ['In', 'really', 'like', 'these.', 'I', 'wear', 'between', 'a', '9-9.5', 'womens,', 'I', 'got', 'the', '9.5', 'and', 'they', 'fit', 'perfectly.', 'They', 'are', 'light', 'weight', 'but', 'have', 'good', 'support.', 'I', 'will', 'buy', 'another', 'pair.']
# ______________
# really like these. wear a 9-9.5 womens, got 9.5 they fit perfectly. are light weight have good support. will buy another pair.
# ['Very', 'speedy', 'delivery', 'and', 'the', 'product', 'was', 'exactly', 'as', 'expected.', 'For', 'anyone', 'who', 'has', 'not', 'used', 'Biolage', 'products,', 'START.', 'The', 'only', 'shampoo/conditioner', 'that', 'actually', 'performs', 'as', 'promised', 'for', 'my', 'very', 'long,', 'very', 'fine,', 'very', 'long', 'hair!', 'Would', 'definitely', 'buy', 'again', 'from', 'this', 'seller!']
# ______________
# speedy delivery the product exactly expected. anyone has not used Biolage products, START. only shampoo/conditioner actually performs promised my long, fine, long hair! Would definitely buy from seller!
# ['Love', 'these', 'Soaps', 'and', 'the', 'Company', 'whom', 'makes', 'them!', '', 'All', 'are', 'amazing..Here', 'is', 'a', 'Wonderful', 'list', 'to', 'help', 'everyone', 'choose', 'there', 'favorite', 'Scents!.Like', 'helping', 'other', 'is..', 'Pre', 'de', 'Provence', 'Pure', 'Vegetable', 'Oil', 'Soap', '-', '8.8', 'oz.', 'bar.With', 'luscious', 'scents', 'and', 'rich', 'lather,', 'these', 'soaps', 'are', 'a', 'customer', 'favorite.', 'Hard-milled', 'to', 'be', 'long-lasting,', 'with', 'Shea', 'Butter', 'and', 'Pure', 'Vegetable', 'Oils', 'to', 'moisturize', 'your', 'skin.', 'Delicately', 'scented', 'and', 'made', 'with', 'all', 'natural', 'ingredients.', 'Individually', 'wrapped', 'bars..Agrumes', '(Citrus', 'Fruits)', 'Light', 'citrus', 'blend', 'of', 'grapefruit,', 'citron,', 'and', 'orange..*Angel', 'is', 'Trumpet', 'Sunny,', 'floral', 'fragrance.', 'Exfoliating..Apple', 'Pear', 'Summer', 'day', 'in', 'the', 'orchard;', 'fresh', 'and', 'fruity..Coconut', 'Luscious...', 'The', 'fragrance', 'of', 'the', 'islands..Green', 'Tea', 'Exotic,', 'sensuous,', 'and', 'tangy..*Honey', 'Almond', 'Honey', 'and', 'Almond', 'blended', 'into', 'the', 'warm,', 'sweet', 'smell', 'of', 'Provence.', 'Exfoliating..Jasmin', 'Exotic', '&', 'floral..*Juicy', 'Pomegranate', 'Fresh,', 'juicy', 'sweet.', 'Exfoliating..*Lavender', 'Lavender,', 'the', 'best', 'alternative', 'to', 'a', 'trip', 'to', 'the', 'south', 'of', 'France!', 'Aromatic', '&', 'woody.', 'Exfoliating..*Lemongrass', 'Tangy,', 'citrusy,', 'and', 'invigorating.', 'Exfoliating..*Lime', 'Zest', 'Earthy,', 'citrusy', 'zeal', 'of', 'the', 'lime.', 'Provides', 'the', 'well', 'being', 'of', 'cheer', 'and', 'revitalization.', 'Exfoliating..Linden', 'Sweet', 'essence', 'of', 'a', 'summer', 'day', 'in', 'Provence.', 'Fresh', '&', 'clean..Milk', 'Clean,', 'sweet,', 'and', 'pleasing..*Mint', 'Leaf', 'Invigorating,', 'refreshing,', 'and', 'restorative.', 'Exfoliating..Mirabelle', 'Juicy,', 'green', 'floral.Moondance', 'Bright,', 'green,', 'floral.Olive', 'Oil', 'Mild', 'scent,', 'highly', 'moisturizing', '&', 'non-allergenic.', 'The', 'very', 'best', 'for', 'dry', 'or', 'sensitive', 'skin..Also', 'good', 'as', 'a', 'baby', 'soap,', 'shaving', 'soap,', 'laundry', 'soap,', 'or', 'kitchen', 'soap..Peony', 'Subtle,', 'sensual,', 'powdery,', 'and', 'romantic..Pineapple', 'Scrumptious...', 'Sweet', 'and', 'fruity..Raspberry', 'Juicy,', 'sunny.*Rose', 'Petal', 'French', 'rose', 'garden', 'in', 'summer.', 'Exfoliating..*Rosemary', 'Mint', 'Fresh,', 'herbaceous.*Sage', 'Herbal,', 'fresh,', 'and', 'exhilarating.', 'Exfoliating..Starflower', 'Sparkling,', 'fruity,', 'floral.*Tiare', 'Tropical,', 'creamy', 'floral.', 'Exfoliating..Verbena', 'Sparkling', 'citrus', 'to', 'excite', 'the', 'senses..Violette', 'Sugared', 'violets.*White', 'Gardenia', 'A', 'beautiful', 'shrub', 'with', 'fragrant', 'white', 'flowers', 'that', 'create', 'a', 'sweet,', 'silky', 'floral.', 'Exfoliating..*', 'Asterisks', 'in', 'the', 'list', 'above', 'indicate', 'soaps', 'with', 'exfoliating', 'visible', 'bits', 'of', 'lavender', 'blossoms,', 'rose', 'petals,', 'apricot', 'rind,', 'lemongrass,', 'sage', 'and', 'mint', 'leaves.', 'Along', 'with', 'the', 'richness', 'of', 'shea', 'butter,', 'these', 'botanicals', 'help', 'to', 'exfoliate', 'dead', 'skin', 'cells', 'leaving', 'skin', 'renewed', 'and', 'soft...']
# ______________
# Love Soaps Company makes them!  amazing..Here Wonderful list help everyone choose favorite Scents!.Like helping is.. Pre de Provence Pure Vegetable Oil Soap - 8.8 oz. bar.With luscious scents rich lather, soaps are a customer favorite. Hard-milled be long-lasting, Shea Butter Pure Vegetable Oils moisturize skin. Delicately scented made all natural ingredients. Individually wrapped bars..Agrumes (Citrus Fruits) Light citrus blend grapefruit, citron, orange..*Angel Trumpet Sunny, floral fragrance. Exfoliating..Apple Pear Summer day orchard; fresh fruity..Coconut Luscious... fragrance islands..Green Tea Exotic, sensuous, tangy..*Honey Almond Honey Almond blended the warm, sweet smell Provence. Exfoliating..Jasmin Exotic & floral..*Juicy Pomegranate Fresh, juicy sweet. Exfoliating..*Lavender Lavender, the best alternative a trip the south France! Aromatic & woody. Exfoliating..*Lemongrass Tangy, citrusy, invigorating. Exfoliating..*Lime Zest Earthy, citrusy zeal the lime. Provides the well cheer revitalization. Exfoliating..Linden Sweet essence a summer day Provence. Fresh & clean..Milk Clean, sweet, pleasing..*Mint Leaf Invigorating, refreshing, restorative. Exfoliating..Mirabelle Juicy, green floral.Moondance Bright, green, floral.Olive Oil Mild scent, highly moisturizing & non-allergenic. very best dry sensitive skin..Also good a baby soap, shaving soap, laundry soap, kitchen soap..Peony Subtle, sensual, powdery, romantic..Pineapple Scrumptious... Sweet fruity..Raspberry Juicy, sunny.*Rose Petal French rose garden summer. Exfoliating..*Rosemary Mint Fresh, herbaceous.*Sage Herbal, fresh, exhilarating. Exfoliating..Starflower Sparkling, fruity, floral.*Tiare Tropical, creamy floral. Exfoliating..Verbena Sparkling citrus excite the senses..Violette Sugared violets.*White Gardenia beautiful shrub fragrant white flowers create a sweet, silky floral. Exfoliating..* Asterisks the list indicate soaps exfoliating visible bits lavender blossoms, rose petals, apricot rind, lemongrass, sage mint leaves. Along the richness of shea butter, botanicals help exfoliate dead skin cells leaving skin renewed soft...
# ['Love', 'these', 'Soaps', 'and', 'the', 'Company', 'whom', 'makes', 'them!', 'All', 'are', 'amazing..Here', 'is', 'a', 'Wonderful', 'list', 'to', 'help', 'everyone', 'choose', 'there', 'favorite', 'Scents!.Like', 'helping', 'other', 'is..Pre', 'de', 'Provence', 'Pure', 'Vegetable', 'Oil', 'Soap', '-', '8.8', 'oz.', 'bar.With', 'luscious', 'scents', 'and', 'rich', 'lather,', 'these', 'soaps', 'are', 'a', 'customer', 'favorite.', 'Hard-milled', 'to', 'be', 'long-lasting,', 'with', 'Shea', 'Butter', 'and', 'Pure', 'Vegetable', 'Oils', 'to', 'moisturize', 'your', 'skin.', 'Delicately', 'scented', 'and', 'made', 'with', 'all', 'natural', 'ingredients.', 'Individually', 'wrapped', 'bars..Agrumes', '(Citrus', 'Fruits)', 'Light', 'citrus', 'blend', 'of', 'grapefruit,', 'citron,', 'and', 'orange..*Angel', 'is', 'Trumpet', 'Sunny,', 'floral', 'fragrance.', 'Exfoliating..Apple', 'Pear', 'Summer', 'day', 'in', 'the', 'orchard;', 'fresh', 'and', 'fruity..Coconut', 'Luscious...', 'The', 'fragrance', 'of', 'the', 'islands..Green', 'Tea', 'Exotic,', 'sensuous,', 'and', 'tangy..*Honey', 'Almond', 'Honey', 'and', 'Almond', 'blended', 'into', 'the', 'warm,', 'sweet', 'smell', 'of', 'Provence.', 'Exfoliating..Jasmin', 'Exotic', '&', 'floral..*Juicy', 'Pomegranate', 'Fresh,', 'juicy', 'sweet.', 'Exfoliating..*Lavender', 'Lavender,', 'the', 'best', 'alternative', 'to', 'a', 'trip', 'to', 'the', 'south', 'of', 'France!', 'Aromatic', '&', 'woody.', 'Exfoliating..*Lemongrass', 'Tangy,', 'citrusy,', 'and', 'invigorating.', 'Exfoliating..*Lime', 'Zest', 'Earthy,', 'citrusy', 'zeal', 'of', 'the', 'lime.', 'Provides', 'the', 'well', 'being', 'of', 'cheer', 'and', 'revitalization.', 'Exfoliating..Linden', 'Sweet', 'essence', 'of', 'a', 'summer', 'day', 'in', 'Provence.', 'Fresh', '&', 'clean..Milk', 'Clean,', 'sweet,', 'and', 'pleasing..*Mint', 'Leaf', 'Invigorating,', 'refreshing,', 'and', 'restorative.', 'Exfoliating..Mirabelle', 'Juicy,', 'green', 'floral.Moondance', 'Bright,', 'green,', 'floral.Olive', 'Oil', 'Mild', 'scent,', 'highly', 'moisturizing', '&', 'non-allergenic.', 'The', 'very', 'best', 'for', 'dry', 'or', 'sensitive', 'skin..Also', 'good', 'as', 'a', 'baby', 'soap,', 'shaving', 'soap,', 'laundry', 'soap,', 'or', 'kitchen', 'soap..Peony', 'Subtle,', 'sensual,', 'powdery,', 'and', 'romantic..Pineapple', 'Scrumptious...', 'Sweet', 'and', 'fruity..Raspberry', 'Juicy,', 'sunny.*Rose', 'Petal', 'French', 'rose', 'garden', 'in', 'summer.', 'Exfoliating..*Rosemary', 'Mint', 'Fresh,', 'herbaceous.*Sage', 'Herbal,', 'fresh,', 'and', 'exhilarating.', 'Exfoliating..Starflower', 'Sparkling,', 'fruity,', 'floral.*Tiare', 'Tropical,', 'creamy', 'floral.', 'Exfoliating..Verbena', 'Sparkling', 'citrus', 'to', 'excite', 'the', 'senses..Violette', 'Sugared', 'violets.*White', 'Gardenia', 'A', 'beautiful', 'shrub', 'with', 'fragrant', 'white', 'flowers', 'that', 'create', 'a', 'sweet,', 'silky', 'floral.', 'Exfoliating..*', 'Asterisks', 'in', 'the', 'list', 'above', 'indicate', 'soaps', 'with', 'exfoliating', 'visible', 'bits', 'of', 'lavender', 'blossoms,', 'rose', 'petals,', 'apricot', 'rind,', 'lemongrass,', 'sage', 'and', 'mint', 'leaves.', 'Along', 'with', 'the', 'richness', 'of', 'shea', 'butter,', 'these', 'botanicals', 'help', 'to', 'exfoliate', 'dead', 'skin', 'cells', 'leaving', 'skin', 'renewed', 'and', 'soft.']
# ______________
# Love Soaps Company makes them! amazing..Here Wonderful list help everyone choose favorite Scents!.Like helping is..Pre de Provence Pure Vegetable Oil Soap - 8.8 oz. bar.With luscious scents rich lather, soaps are a customer favorite. Hard-milled be long-lasting, Shea Butter Pure Vegetable Oils moisturize skin. Delicately scented made all natural ingredients. Individually wrapped bars..Agrumes (Citrus Fruits) Light citrus blend grapefruit, citron, orange..*Angel Trumpet Sunny, floral fragrance. Exfoliating..Apple Pear Summer day orchard; fresh fruity..Coconut Luscious... fragrance islands..Green Tea Exotic, sensuous, tangy..*Honey Almond Honey Almond blended the warm, sweet smell Provence. Exfoliating..Jasmin Exotic & floral..*Juicy Pomegranate Fresh, juicy sweet. Exfoliating..*Lavender Lavender, the best alternative a trip the south France! Aromatic & woody. Exfoliating..*Lemongrass Tangy, citrusy, invigorating. Exfoliating..*Lime Zest Earthy, citrusy zeal the lime. Provides the well cheer revitalization. Exfoliating..Linden Sweet essence a summer day Provence. Fresh & clean..Milk Clean, sweet, pleasing..*Mint Leaf Invigorating, refreshing, restorative. Exfoliating..Mirabelle Juicy, green floral.Moondance Bright, green, floral.Olive Oil Mild scent, highly moisturizing & non-allergenic. very best dry sensitive skin..Also good a baby soap, shaving soap, laundry soap, kitchen soap..Peony Subtle, sensual, powdery, romantic..Pineapple Scrumptious... Sweet fruity..Raspberry Juicy, sunny.*Rose Petal French rose garden summer. Exfoliating..*Rosemary Mint Fresh, herbaceous.*Sage Herbal, fresh, exhilarating. Exfoliating..Starflower Sparkling, fruity, floral.*Tiare Tropical, creamy floral. Exfoliating..Verbena Sparkling citrus excite the senses..Violette Sugared violets.*White Gardenia beautiful shrub fragrant white flowers create a sweet, silky floral. Exfoliating..* Asterisks the list indicate soaps exfoliating visible bits lavender blossoms, rose petals, apricot rind, lemongrass, sage mint leaves. Along the richness of shea butter, botanicals help exfoliate dead skin cells leaving skin renewed soft.
# ...
# ['Luv', 'them!!']
# ______________
# Luv them!!
# ['just', 'what', 'I', 'wanted', 'and', 'at', 'a', 'great', 'price']
# ______________
# what wanted at great price
# ['Bought', 'along', 'with', 'their', 'shampoo', 'and', 'lotion', 'for', 'a', 'welcome', 'gift', 'for', 'an', 'oceanfront', 'condo', 'rental', 'and', 'are', 'perfect', 'size', 'and', 'price.']
# ______________
# Bought along their shampoo lotion a welcome gift an oceanfront condo rental are perfect size price.
# ['I', 'love', 'these,', 'I', 'had', 'the', 'previous', 'iteration', '(or', 'maybe', 'two', 'earlier?)', 'and', 'finally', 'wore', 'them', 'out', 'after', 'several', 'years.', 'They', 'are', 'definitely', 'a', 'light-weight', 'training', 'shoe', 'so', 'I', 'would', 'not', 'get', 'them', 'if', 'you', 'are', 'going', 'to', 'be', 'doing', 'a', 'lot', 'of', 'running.', 'But', 'this', 'also', 'makes', 'them', 'extremely', 'comfortable,', 'I', 'had', 'not', 'realized', 'how', 'hot', 'running', 'shoes', 'made', 'my', 'feet', 'until', 'I', 'switched', 'to', 'these.', 'Good', 'support', 'and', 'my', 'feet', 'stay', 'cool', 'all', 'day,', 'also', 'noticeably', 'light', 'but', 'well-made', 'and', 'long', 'lasting..I', 'have', 'worn', 'them', 'hiking', 'in', 'a', 'pinch', 'but', 'do', 'not', 'really', 'recommend', 'it', 'because', 'the', 'material', 'is', 'mesh-like', 'and', 'will', 'let', 'a', 'lot', 'of', 'dirt', 'in.', 'But', 'if', 'you', 'mainly', 'take', 'cardio', 'classes', 'and/or', 'do', 'weight', 'training', 'or', 'just', 'need', 'something', 'to', 'wear', 'around', 'town', 'look', 'no', 'further.']
# ______________
# love these, had previous iteration (or maybe two earlier?) finally wore out several years. are definitely light-weight training shoe would not get if are going be lot running. this makes extremely comfortable, I had not realized hot running shoes made feet I switched these. Good support my feet stay cool day, noticeably light well-made long lasting..I worn hiking a pinch not really recommend because material mesh-like will let a lot dirt in. if mainly take cardio classes and/or do weight training just need something wear around town look no further.
# ['Artculo', 'equivocado', 'en', 'color']
# ______________
# Artculo equivocado en color
# ['Will', 'buy', 'again']
# ______________
# Will buy
# ['Super.']
# ______________
# Super.
# ['daughter', 'loves', 'them']
# ______________
# daughter loves
# ['This', 'shower', 'gel', 'went', 'above', 'my', 'expectation.', 'This', 'was', 'not', 'overpowering', 'like', 'other', 'shower', 'gels', 'full', 'of', 'musky', 'cologne..I', 'have', 'sensitive', 'skin', 'so', 'this', 'went', 'on', 'my', 'skin', 'without', 'a', 'problem.', 'Thanks', 'for', 'the', 'fast', 'shipping.']
# ______________
# shower gel went my expectation. was not overpowering like shower gels full musky cologne..I sensitive skin this went my skin without problem. Thanks the fast shipping.
# ['I', 'wish', 'this', 'were', 'not', 'a', 'discontinued', 'product.', 'But', 'I', 'am', 'glad', 'I', 'found', 'what', 'is', 'left', 'of', 'it!', 'Great', 'product!']
# ______________
# wish were not discontinued product. glad I found is left it! Great product!
# ['Finally,', 'after', 'trying', 'about', '10', 'pairs', 'of', 'Nike', 'is,', 'these', 'were', 'a', 'perfect', 'fit.', '', 'They', 'are', 'light', 'and', 'very', 'comfortable,', 'I', 'really', 'just', 'forget', 'about', 'my', 'feet', 'when', 'I', 'am', 'wearing', 'them.']
# ______________
# Finally, trying 10 pairs Nike is, were perfect fit.  are light very comfortable, really forget my feet I wearing them.
# ['This', 'one', 'is', 'a', 'winner', 'I', 'can', 'not', 'afford', 'the', "J'Adore", 'original', 'but', 'this', 'is', 'very', 'close', 'reminds', 'me', 'of', 'Perry', 'Ellis', '360', '(circa', '1990s)', 'but', 'I', 'like', 'it']
# ______________
# one a winner can not afford J'Adore original this very close reminds of Perry Ellis 360 (circa 1990s) I like
# ['The', 'price', 'for', 'an', 'Hermes', 'product', 'is', 'the', 'best']
# ______________
# price an Hermes product the best
# ['Would', 'not', 'use', 'any', 'other', 'conditioner.', '', 'I', 'use', 'it', 'at', 'least', 'every', '2', 'weeks', 'to', 'keep', 'my', 'white', 'hair', 'shining', 'and', 'healthy!']
# ______________
# Would not use other conditioner.  use at least every 2 weeks keep white hair shining healthy!
# ['fits', 'perfect,', 'my', 'daughter', 'loves', 'them']
# ______________
# fits perfect, daughter loves
# ['I', 'just', 'got', 'out', 'of', 'the', 'shower', 'after', 'using', 'this.', 'The', 'product', 'cleanses', 'well', 'and', 'is', 'very', 'creamy.', 'I', 'used', 'it', 'with', 'my', 'scrub', 'brush', 'to', 'get', 'some', 'exfoliating', 'going', 'too.', 'Even', 'shaved', 'my', 'legs', 'with', 'this', 'product.', 'Ca', 'not', 'complain', 'at', 'the', 'moment,', 'except', 'my', 'skin', 'feels', 'dryer.', 'Overall,', 'this', 'was', 'a', 'fine', 'cleanser', 'and', 'if', 'anything,', 'it', 'strips', 'every', 'bit', 'of', 'oil', 'out', 'of', 'your', 'skin.', 'The', 'feeling', 'I', 'am', 'getting', 'is', 'not', 'tingling', 'from', 'squeaky', 'clean,', 'it', 'is', 'more', 'like', 'a', 'bit', 'tight.', 'But', 'it', 'definitely', 'cleaned', 'well.', 'I', 'do', 'not', 'see', 'any', 'eczema', 'or', 'psoriasis', 'and', 'I', 'have', 'not', 'put', 'any', 'lotions', 'on,', 'as', 'I', 'normally', 'do', 'after', 'I', 'shower.', 'Now', 'I', 'must', 'go', 'apply', 'lotion', 'to', 'my', 'arms', 'and', 'legs', 'and', 'facial', 'products', 'to', 'my', 'face.']
# ______________
# just got shower using this. product cleanses well creamy. used scrub brush get exfoliating going too. Even shaved legs with product. Ca not complain the moment, except skin feels dryer. Overall, this was fine cleanser if anything, strips every bit of oil of skin. feeling am getting is not tingling squeaky clean, is like bit tight. it definitely cleaned well. not see eczema psoriasis not put lotions on, normally do after I shower. Now I must go apply lotion my arms legs facial products my face.
# ['The', '150', 'gram', 'bar', 'of', 'Mint', 'Leaf', 'Pre', 'de', 'Provence', 'Shea', 'Butter', 'Soap', 'is', 'delightful.', 'The', 'soap', 'has', 'little', 'bits', 'of', 'mint', 'leaf', 'in', 'the', 'bar', 'that', 'you', 'can', 'see.', 'The', 'soap', 'is', 'great', 'for', 'bathing', 'with', 'or', 'even', 'washing', 'your', 'face', 'because', 'it', 'has', 'shea', 'butter', 'as', 'part', 'of', 'the', 'ingredients.', 'It', 'also', 'has', 'fragrance', 'added,', 'which', 'helps', 'enhance', 'the', 'aroma', 'from', 'the', 'soap.', 'This', 'is', 'a', 'French', 'milled', 'soap', 'and', 'you', 'can', 'feel', 'the', 'difference', 'when', 'you', 'wash', 'your', 'hands', 'or', 'your', 'body.', 'This', 'is', 'a', 'luxury', 'soap', 'and', 'will', 'make', 'wonderful', 'gifts', 'also.', 'I', 'do', 'not', 'have', 'a', 'single', 'negative', 'thing', 'to', 'say', 'about', 'this', 'soap.', 'The', 'soaps', 'come', 'in', '150', 'and', '250', 'gram', 'sizes.', 'These', 'are', 'the', 'soaps', 'you', 'want', 'to', 'soak', 'in', 'the', 'tub', 'with', 'and', 'enjoy', 'the', 'feel,', 'the', 'scent', 'and', 'the', 'calmness', 'from', 'the', 'scents.']
# ______________
# 150 gram bar Mint Leaf Pre de Provence Shea Butter Soap delightful. soap little bits mint leaf bar see. soap great bathing even washing face it shea butter part ingredients. also fragrance added, helps enhance aroma soap. is French milled soap you feel difference you wash hands or your body. is luxury soap will make wonderful gifts also. do not a single negative thing say this soap. soaps come 150 250 gram sizes. are the soaps you want soak the tub enjoy the feel, the scent and the calmness the scents.
# ['Everyone', 'has', 'a', 'need', 'for', 'a', 'nail', 'brush.', 'On', 'the', 'top', 'of', 'the', 'unit,', 'you', 'get', 'a', 'tight', 'row', 'of', 'curved', 'bristles,', 'which', 'are', 'great', 'for', 'getting', 'under', 'your', 'nails.', 'The', 'bottom', 'is', 'all', 'brush', 'and', 'you', 'can', 'use', 'it', 'to', 'remove', 'dead', 'skin', 'and', 'overgrown', 'cuticles.', 'Works', 'best', 'wet', 'and', 'with', 'soap.', 'It', 'is', 'easy', 'to', 'hold.', 'After', 'using,', 'you', 'will', 'want', 'to', 'let', 'it', 'air', 'dry', 'and', 'keep', 'it', 'away', 'from', 'water', 'and', 'steam', 'when', 'you', 'are', 'not', 'using,', 'I', 'say', 'this', 'because', 'I', 'have', 'had', 'to', 'throw', 'more', 'than', 'one', 'bristled', 'brush', 'away', 'because', 'they', 'get', 'mildew', 'when', 'you', 'leave', 'them', 'in', 'a', 'shower.']
# ______________
# Everyone need nail brush. the top the unit, get a tight row curved bristles, great getting your nails. bottom all brush use remove dead skin overgrown cuticles. Works best wet with soap. is easy hold. using, you will want to let air dry keep away water steam you are not using, say have to throw than one bristled brush away because they get mildew you leave in a shower.
# ['This', 'soap', 'smells', 'so', 'good', '-', 'clean', 'and', 'intriguing', '-', 'that', 'anyone', 'who', 'uses', 'it', 'in', 'my', 'home', 'comments', 'on', 'it.', 'It', 'is', 'not', 'in', 'any', 'stores', 'in', 'my', 'town', 'so', 'I', 'found', 'it', 'online', 'and', 'ordered', 'it', '-', 'not', 'some', 'thing', 'I', 'usually', 'do.']
# ______________
# soap smells good - clean intriguing - anyone uses home comments it. is not any stores in my town found online ordered - not thing I usually do.
# ['Great', 'product,', 'I', 'had', 'no', 'issues', 'and', 'love', 'the', 'way', 'it', 'smelled', 'and', 'how', 'it', 'made', 'my', 'skin', 'feel.']
# ______________
# Great product, had no issues love way smelled how made skin feel.
# ['By', 'far', 'my', 'favorite', 'fragrance', 'and', 'this', 'is', 'the', 'perfect', 'size.', 'Great', 'for', 'gifts', 'too', 'since', 'it', 'comes', 'pre-packed', 'with', 'a', 'ribbon.']
# ______________
# far favorite fragrance this the perfect size. Great gifts since comes pre-packed a ribbon.
# ['I', 'really', 'like', 'this', 'wash', 'and', 'was', 'feeling', 'lazy', 'so', 'I', 'decided', 'to', 'buy', 'it', 'on', 'amazon.', 'Just', 'be', 'advised', 'its', 'about', '3-4', 'times', 'more', 'expensive', 'on', 'amazon', 'than', 'in', 'most', 'stores.']
# ______________
# really like wash was feeling lazy I decided buy amazon. be advised about 3-4 times expensive on amazon in stores.
# ['I', 'received', 'my', 'item', 'before', 'the', 'expected', 'date.', 'I', 'am', 'very', 'pleased.']
# ______________
# received item the expected date. am pleased.
# ['My', 'favorite!!!!!']
# ______________
# favorite!!!!!
# ['cheap']
# ______________
# cheap
# ['Effective', 'soap', 'and', 'shampoo', '-', 'convenient', 'to', 'have', 'one', 'bottle', 'to', 'do', 'both.', '', 'Clean', 'scent', 'and', 'does', 'the', 'job.']
# ______________
# Effective soap shampoo - convenient have one bottle do both.  Clean scent does job.
# ['Great', 'anti-frizz', 'product!']
# ______________
# Great anti-frizz product!
# ['I', 'really', 'like', 'using', 'organic', 'products', 'and', 'this', 'product', 'had', 'awesome', 'reviews.', 'Ive', 'been', 'seeing', 'a', 'dermatologist', 'for', 'my', 'psoriasis', 'and', 'received', 'a', 'much', 'of', 'topical', 'cream', 'and', 'even', 'steroid', 'injections.', 'So', 'I', 'wanted', 'to', 'go', 'more', 'oganic.', 'It', 'still', 'did', 'not', 'work', 'and', 'Ive', 'used', 'the', 'whole', 'bottle.', 'It', 'did', 'not', 'even', 'help', 'improve', 'it', 'any', 'bit.', 'Im', 'sure', 'this', 'may', 'work', 'for', 'someone', 'else', 'but', 'it', 'did', 'not', 'for', 'me.']
# ______________
# really like using organic products product awesome reviews. Ive seeing dermatologist my psoriasis received much topical cream even steroid injections. I wanted go oganic. still not work Ive used whole bottle. not even help improve any bit. Im sure this may work someone else it did not me.
# ['love', 'them!']
# ______________
# love them!
# ['Fit', 'true', 'to', 'size']
# ______________
# Fit true size
# ['Excellent', 'products.', 'Will', 'purchase', 'more', 'in', 'a', 'heartbeat!']
# ______________
# Excellent products. Will purchase in heartbeat!
# ['My', 'sister', 'smiled', 'from', 'ear', 'to', 'ear.']
# ______________
# sister smiled ear ear.
# ['WOW!', '', 'I', 'love', 'these', 'capris!', '', 'I', 'ordered', 'the', 'deep', 'teal', 'and', 'they', 'are', 'a', 'very', 'dark', 'blue/teal', '(a', 'much', 'deeper', 'prettier', 'color', 'than', 'shown).', '', 'I', 'received', 'many', 'compliments', 'the', 'first', 'time', 'I', 'wore', 'them', 'to', 'the', 'gym.', '', 'They', 'are', 'super', 'soft', 'and', 'comfortable', 'from', 'the', 'leg', 'all', 'the', 'way', 'to', 'the', 'waist...COMFORTABLE.', '', 'They', 'never', 'slip', 'down', 'at', 'the', 'waist', 'and', 'give', 'me', 'full', 'coverage', '(not', 'see', 'through', 'at', 'all).', 'I', 'am', "5'", '4"', 'and', '159', 'pounds', 'and', 'I', 'ordered', 'a', 'medium.', '', 'The', 'size', 'fit', 'perfectly', 'although', 'that', 'being', 'said', 'they', 'are', 'longer', 'on', 'me', 'than', 'the', 'photo', '(probably', 'my', 'short', 'legs)', 'but', 'came', '2', 'inches', 'above', 'my', 'ankle', 'so', 'just', 'below', 'my', 'calf.', '', 'Given', 'that', 'I', 'have', 'weight', 'to', 'loose', 'these', 'are', 'very', 'flattering', 'on', 'as', 'well.', '', 'They', 'are', 'also', 'a', 'nice', 'stretchy', 'fabric', '(thus', 'the', 'comfort)', 'and', 'cool.', '', 'We', 'are', 'in', 'the', 'high', '90', 'is', 'and', '100', 'degree', 'summer', 'weather', 'and', 'I', 'am', 'cool!', '', 'Purchase', 'these', 'as', 'you', 'will', 'not', 'be', 'disappointed', 'especially', 'at', 'this', 'price.', '', 'I', 'like', 'these', 'better', 'than', 'my', 'Lululemon', 'and', 'Athleta', 'capris!!!', '', 'I', 'am', 'back', 'to', 'purchase', 'more!']
# ______________
# WOW!  love capris!  ordered deep teal dark blue/teal (a much deeper prettier color shown).  received many compliments first time wore gym.  are super soft comfortable leg way the waist...COMFORTABLE.  never slip the waist give full coverage (not see at all). 5' 4" 159 pounds ordered a medium.  size fit perfectly although being said they are longer me the photo (probably short legs) came 2 inches my ankle just my calf.  Given weight loose are flattering as well.  are a nice stretchy fabric (thus the comfort) cool.  are the high 90 100 degree summer weather I am cool!  Purchase as will not disappointed especially at this price.  I like better my Lululemon and Athleta capris!!!  I am back to purchase more!
# ['I', 'have', 'gotten', 'so', 'many', 'compliments', 'on', 'the', 'blue', 'color', 'and', 'look', 'of', 'this', 'shoe.', '', 'It', 'is', 'super', 'comfortable.', '', 'The', 'grip', 'is', 'wonderful', 'for', 'my', 'indoor', 'gym', 'cross', 'training', 'classes.', '', 'I', 'always', 'order', 'a', 'half', 'size', 'larger', 'in', 'Nike', 'brand', 'shoes', 'and', 'thy', 'fit', 'perfectly', 'as', 'I', 'did', 'with', 'this', 'shoe.']
# ______________
# have gotten many compliments the blue color look shoe.  super comfortable.  grip is wonderful my indoor gym cross training classes.  always order half size larger Nike brand shoes thy fit perfectly I with this shoe.
# ['Typical', 'Hanes', 'quality.', 'Good', 'weight,', 'sized', 'just', 'right,', 'made', 'pretty', 'well']
# ______________
# Typical Hanes quality. Good weight, sized right, made pretty well
# ['Size,', 'colour', 'and', 'print', 'all', 'above', 'average', 'but', 'does', 'not', 'wash', 'great.']
# ______________
# Size, colour print above average does not wash great.
# ['Great', 'product', '-', 'kids', 'love', 'it', 'and', 'it', 'smells', 'good,', 'too.', '', 'Easily', 'rinses', 'out', 'of', 'hair', 'and', 'leaves', 'hair', 'nicely', 'manageable.']
# ______________
# Great product - kids love smells good, too.  Easily rinses of hair and leaves hair nicely manageable.
# ['extremely', 'pleased,', 'very', 'pleasant', 'scent,', 'very', 'longlasting...']
# ______________
# extremely pleased, pleasant scent, longlasting...
# ['My', 'favorite']
# ______________
# favorite
# ['Very', 'good', 'product----I', 'use', 'it', 'every', 'day']
# ______________
# good product----I use every day

# %%
sorted_df.head()
# Out:
#       overall  verified   reviewTime      reviewerID        asin  \
# 4924      5.0     False  08 26, 2017  A2MJ8OL2FYN7CW  B00W259T7G
# 4187      5.0     False   09 4, 2017  A2MJ8OL2FYN7CW  B001LNODUS
# 4856      5.0     False  09 21, 2017  A2MJ8OL2FYN7CW  B00W259T7G
# 4849      5.0     False  09 27, 2017  A2MJ8OL2FYN7CW  B00W259T7G
# 4848      5.0     False  09 27, 2017  A2MJ8OL2FYN7CW  B00W259T7G
#
#                                                 style reviewerName  \
# 4924   {'Size:': ' 250 Gram', 'Color:': ' Olive Oil'}     Lynne E.
# 4187                        {'Color:': ' Shower Gel'}     Lynne E.
# 4856    {'Size:': ' 150 Gram', 'Color:': ' Sea Salt'}     Lynne E.
# 4849  {'Size:': ' 250 Gram', 'Color:': ' Sandalwood'}     Lynne E.
# 4848   {'Size:': ' 250 Gram', 'Color:': ' Patchouli'}     Lynne E.
#
#                                              reviewText  \
# 4924  This PRE DE PROVENCE SHEA BUTTER ENRICHED ARTI...
# 4187  Lavender is my favorite soap fragrance, so it ...
# 4856  I love Pre de Provence soaps, but was intensel...
# 4849  This PRE DE PROVENCE Sandalwood SHEA BUTTER EN...
# 4848  This PRE DE PROVENCE PATCHOULI SHEA BUTTER ENR...
#
#                                                 summary  unixReviewTime vote  \
# 4924    Feels Luxurious, Doesn't Dry Out Sensitive Skin      1503705600  NaN
# 4187  Clear Gel Creates Nice Lather With Delicate La...      1504483200  NaN
# 4856  Luxurious French Soap Has Fresh Sea Breeze Fra...      1505952000    7
# 4849  Luxurious French Soap With Mild, Masculine Fra...      1506470400  NaN
# 4848  Luxurious French Soap With Musky Masculine Fra...      1506470400  NaN
#
#      image   unixTime  Score  \
# 4924   NaN 2017-08-26      1
# 4187   NaN 2017-09-04      1
# 4856   NaN 2017-09-21      1
# 4849   NaN 2017-09-27      1
# 4848   NaN 2017-09-27      1
#
#                                       Text_preprocessed
# 4924  PRE DE PROVENCE SHEA BUTTER ENRICHED ARTISANAL...
# 4187  Lavender favorite soap fragrance, it no surpri...
# 4856  love Pre de Provence soaps, was intensely curi...
# 4849  PRE DE PROVENCE Sandalwood SHEA BUTTER ENRICHE...
# 4848  PRE DE PROVENCE PATCHOULI SHEA BUTTER ENRICHED...
